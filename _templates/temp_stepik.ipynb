# %% [markdown]
# # step_
#
# ## sample_input:
#
# ## sample_output:

# %%
# date:

# %% [markdown]
# -----

# %% [markdown]
# # step_
#
# ## sample_input:
#
# ## sample_output:

# %%
# date:

# %% [markdown]
# -----

# %% [markdown]
# # step_
#
# ## sample_input:
#
# ## sample_output:

# %%
# date:

# %% [markdown]
# -----

# %% [markdown]
# # step_
#
# ## sample_input:
#
# ## sample_output:

# %%
# date:

# %% [markdown]
# -----

# %% [markdown]
# # step_
#
# ## sample_input:
#
# ## sample_output:

# %%
# date:

# %% [markdown]
# -----

# %% [markdown]
# # step_
#
# ## sample_input:
#
# ## sample_output:

# %%
# date:

# %% [markdown]
# -----

# %% [markdown]
# # step_
#
# ## sample_input:
#
# ## sample_output:

# %%
# date:

# %% [markdown]
# -----

# %% [markdown]
# # step_
#
# ## sample_input:
#
# ## sample_output:

# %%
# date:

# %% [markdown]
# -----

# %% [markdown]
# # step_
#
# ## sample_input:
#
# ## sample_output:

# %%
# date:

# %% [markdown]
# -----

# %% [markdown]
# # step_
#
# ## sample_input:
#
# ## sample_output:

# %%
# date:
