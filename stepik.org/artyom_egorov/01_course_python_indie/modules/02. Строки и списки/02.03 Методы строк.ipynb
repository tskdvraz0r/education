# %%
import pytest
import ipytest
from loguru import logger

# %%
ipytest.autoconfig()

logger.add(
    sink="../../logs/logs.json",
    level="DEBUG",
    format="{file} {function} {extra} {time} {level} {message}",
    colorize=True,
    serialize=True,
    backtrace=True,
    diagnose=True,
    enqueue=True,
    rotation="1 Mb",
    retention="1 day",
    compression="zip",
)
# Out:
# 1

# %% [markdown]
# # Step 3

# %%
# %%ipytest -v
#
# def upper_string(string: str) -> str:
#     logger.debug(f"{string=}: {type(string)}")
#     if not isinstance(string, str):
#         error_message: str = "Неправильный тип данных;"
#         logger.error(error_message)
#         raise TypeError(error_message)
#
#     return string.upper()
#
# @pytest.mark.parametrize(
#     ["test_string", "expected_result"],
#     [
#         ("test_string", "TEST_STRING"),
#         ("i love python", "I LOVE PYTHON"),
#         ("Еще одна СтРока", "ЕЩЕ ОДНА СТРОКА")
#     ]
# )
# def test_upper_string(
#         test_string: str,
#         expected_result: str,
# ) -> None:
#     assert upper_string(test_string) == expected_result
#
# if __name__ == "__main__":
#     try:
#         logger.info("Запуск функции 'upper_string';")
#         print(upper_string(string="some text"))
#         logger.info("Функция 'upper_string' успешно завершена;")
#     except Exception as e:
#         error_message: str = "Ошибка выполнения в функции 'upper_string';"
#         logger.error(error_message)
# Out:
# 2024-08-04 01:22:18.738 | INFO     | __main__:<module>:26 - Запуск функции 'upper_string';
# 2024-08-04 01:22:18.769 | DEBUG    | __main__:upper_string:2 - string='some text': <class 'str'>
# 2024-08-04 01:22:18.780 | INFO     | __main__:<module>:28 - Функция 'upper_string' успешно завершена;
# SOME TEXT
# ======================================= test session starts ========================================
# platform darwin -- Python 3.12.4, pytest-8.3.2, pluggy-1.5.0
# rootdir: /Users/dmitrijkolganov/Yandex.Disk.localized/git/education/stepik.org/artyom_egorov/01_course_python_indie/modules/02. Строки и списки
# collected 3 items
#
# t_0c063925ecbb4899af65306f355a1cba.py
# 2024-08-04 01:22:18.834 | DEBUG    | __main__:upper_string:2 - string='test_string': <class 'str'>
# .
# 2024-08-04 01:22:18.836 | DEBUG    | __main__:upper_string:2 - string='i love python': <class 'str'>
# .
# 2024-08-04 01:22:18.840 | DEBUG    | __main__:upper_string:2 - string='Еще одна СтРока': <class 'str'>
# ...

# %% [markdown]
# # Step 4

# %%
# %%ipytest -v
#
# def lower_string(string: str) -> str:
#     logger.debug(f"{string=}: {type(string)}")
#     if not isinstance(string, str):
#         error_message: str = "Неправильный тип данных;"
#         logger.error(error_message)
#         raise TypeError(error_message)
#
#     return string.lower()
#
# @pytest.mark.parametrize(
#     ["test_string", "expected_result"],
#     [
#         ("TEST_STRING", "test_string"),
#         ("I LOVE PYTHON", "i love python"),
#         ("ЕЩЕ ОДНА СТРОКА", "еще одна строка")
#     ]
# )
# def test_lower_string(
#         test_string: str,
#         expected_result: str,
# ) -> None:
#     assert lower_string(test_string) == expected_result
#
# if __name__ == "__main__":
#     try:
#         logger.info("Запуск функции 'lower_string';")
#         print(lower_string(string="SoMe TeXt"))
#         logger.info("Функция 'lower_string' успешно завершена;")
#     except Exception as e:
#         error_message: str = "Ошибка выполнения в функции 'lower_string';"
#         logger.error(error_message)
# Out:
# 2024-08-04 01:22:18.856 | INFO     | __main__:<module>:26 - Запуск функции 'lower_string';
# 2024-08-04 01:22:18.859 | DEBUG    | __main__:lower_string:2 - string='SoMe TeXt': <class 'str'>
# 2024-08-04 01:22:18.863 | INFO     | __main__:<module>:28 - Функция 'lower_string' успешно завершена;
# some text
# ======================================= test session starts ========================================
# platform darwin -- Python 3.12.4, pytest-8.3.2, pluggy-1.5.0
# rootdir: /Users/dmitrijkolganov/Yandex.Disk.localized/git/education/stepik.org/artyom_egorov/01_course_python_indie/modules/02. Строки и списки
# collected 3 items
#
# t_0c063925ecbb4899af65306f355a1cba.py
# 2024-08-04 01:22:18.894 | DEBUG    | __main__:lower_string:2 - string='TEST_STRING': <class 'str'>
# .
# 2024-08-04 01:22:18.897 | DEBUG    | __main__:lower_string:2 - string='I LOVE PYTHON': <class 'str'>
# .
# 2024-08-04 01:22:18.899 | DEBUG    | __main__:lower_string:2 - string='ЕЩЕ ОДНА СТРОКА': <class 'str'>
# ...

# %% [markdown]
# # Step 5

# %%
# %%ipytest -v
#
# def is_strings_equal(
#         strings: list[str],
#         is_stdin: bool = False,
# ) -> bool:
#     logger.debug(f"{strings=}: {type(strings)}")
#     logger.debug(f"{is_stdin=}: {type(is_stdin)}")
#
#     # Проверка типов переданных аргументов;
#     for value, value_type in zip(
#             (strings, is_stdin),
#             (list, bool)
#     ):
#         if not isinstance(value, value_type):
#             error_message: str = "Некорректный тип данных;"
#             logger.error(error_message)
#             raise TypeError(error_message)
#
#     # Проверка количества элементов в списке;
#     if len(strings) !=  2:
#         error_message: str = "Некорректное количество элементов;"
#         logger.error(error_message)
#         raise ValueError(error_message)
#
#     # Проверка типов элементов списка;
#     if not all(isinstance(x, str) for x in strings):
#         error_message: str = "Некорректный тип данных элемента;"
#         logger.error(error_message)
#         raise TypeError(error_message)
#
#     return strings[0].strip().lower() == strings[1].strip().lower()
#
# @pytest.mark.parametrize(
#     ["test_strings", "test_is_stdin", "expected_result"],
#     [
#         (["test_string", "test_string"], False, True),
#         (["pswrd1", "PSWd1"], False, False),
#         (["test_string\n", "test_string"], True, True),
#         (["pswrd1\n", "PSWd1"], True, False),
#     ]
# )
# def test_is_strings_equal(
#         test_strings: list[str],
#         test_is_stdin: bool,
#         expected_result: bool,
# ) -> None:
#     assert is_strings_equal(
#         strings=test_strings,
#         is_stdin=test_is_stdin,
#     ) == expected_result
#
# if __name__ == "__main__":
#     try:
#         logger.info("Запуск функции 'is_strings_equal';")
#         print(
#             is_strings_equal(
#                 strings=["password", "passWord"],
#                 is_stdin=False
#             )
#         )
#         logger.info("Функция 'is_strings_equal' успешно завершена;")
#     except Exception as e:
#         error_message: str = "Ошибка выполнения в функции 'is_strings_equal';"
#         logger.error(error_message)
# Out:
# 2024-08-04 01:22:18.917 | INFO     | __main__:<module>:53 - Запуск функции 'is_strings_equal';
# 2024-08-04 01:22:18.918 | DEBUG    | __main__:is_strings_equal:5 - strings=['password', 'passWord']: <class 'list'>
# 2024-08-04 01:22:18.919 | DEBUG    | __main__:is_strings_equal:6 - is_stdin=False: <class 'bool'>
# 2024-08-04 01:22:18.921 | INFO     | __main__:<module>:60 - Функция 'is_strings_equal' успешно завершена;
# True
# ======================================= test session starts ========================================
# platform darwin -- Python 3.12.4, pytest-8.3.2, pluggy-1.5.0
# rootdir: /Users/dmitrijkolganov/Yandex.Disk.localized/git/education/stepik.org/artyom_egorov/01_course_python_indie/modules/02. Строки и списки
# collected 4 items
#
# t_0c063925ecbb4899af65306f355a1cba.py
# 2024-08-04 01:22:18.952 | DEBUG    | __main__:is_strings_equal:5 - strings=['test_string', 'test_string']: <class 'list'>
# ...

# %% [markdown]
# # Step 6

# %%
# %%ipytest -v
#
# def first_and_last_three_chars_is_upper(string: str) -> str:
#     logger.debug(f"{string=}: {type(string)}")
#
#     # Проверка типа переданного аргумента;
#     if not isinstance(string, str):
#         error_message: str = "Неправильный тип данных;"
#         logger.error(error_message)
#         raise TypeError(error_message)
#
#     return string[:3].upper() + string[3:-3].lower() + string[-3:].upper()
#
# @pytest.mark.parametrize(
#     ["test_string", "expected_result"],
#     [
#         ("pyThon", "PYTHON"),
#         ("прогРаммирОВАНИЕ", "ПРОграммироваНИЕ"),
#         ("тестовая строка, которая точно будет норм!", "ТЕСтовая строка, которая точно будет ноРМ!")
#     ]
# )
# def test_first_and_last_three_chars_is_upper(
#         test_string: str,
#         expected_result: str,
# ) -> None:
#     assert first_and_last_three_chars_is_upper(string=test_string) == expected_result
#
# if __name__ == "__main__":
#     try:
#         logger.info("Запуск функции 'first_and_last_three_chars_is_upper';")
#         print(
#             first_and_last_three_chars_is_upper(string="some text")
#         )
#         logger.info("Функция 'first_and_last_three_chars_is_upper' успешно завершена;")
#     except Exception as e:
#         error_message: str = "Ошибка выполнения в функции 'first_and_last_three_chars_is_upper';"
#         logger.error(error_message)
# Out:
# 2024-08-04 01:22:18.981 | INFO     | __main__:<module>:28 - Запуск функции 'first_and_last_three_chars_is_upper';
# 2024-08-04 01:22:18.983 | DEBUG    | __main__:first_and_last_three_chars_is_upper:2 - string='some text': <class 'str'>
# 2024-08-04 01:22:18.985 | INFO     | __main__:<module>:32 - Функция 'first_and_last_three_chars_is_upper' успешно завершена;
# SOMe tEXT
# ======================================= test session starts ========================================
# platform darwin -- Python 3.12.4, pytest-8.3.2, pluggy-1.5.0
# rootdir: /Users/dmitrijkolganov/Yandex.Disk.localized/git/education/stepik.org/artyom_egorov/01_course_python_indie/modules/02. Строки и списки
# collected 3 items
#
# t_0c063925ecbb4899af65306f355a1cba.py
# 2024-08-04 01:22:19.015 | DEBUG    | __main__:first_and_last_three_chars_is_upper:2 - string='pyThon': <class 'str'>
# .
# ...

# %% [markdown]
# # Step 7

# %%
# %%ipytest -v
#
# def swap_register(string: str) -> str:
#     logger.debug(f"{string=}: {type(string)}")
#
#     # Проверка типа переданного аргумента;
#     if not isinstance(string, str):
#         error_message: str = "Неправильный тип данных;"
#         logger.error(error_message)
#         raise TypeError(error_message)
#
#     return string.swapcase()
#
# @pytest.mark.parametrize(
#     ["test_string", "expected_result"],
#     [
#         ("test_string", "TEST_STRING"),
#         ("прогРаммирОВАНИЕ", "ПРОГрАММИРование"),
#         ("Я у мАмы ХацКер", "я У МаМЫ хАЦкЕР")
#     ]
# )
# def test_swap_register(
#         test_string: str,
#         expected_result: str,
# ) -> None:
#     assert swap_register(string=test_string) == expected_result
#
# if __name__ == "__main__":
#     try:
#         logger.info("Запуск функции 'swap_register';")
#         print(swap_register(string="some text"))
#         logger.info("Функция 'swap_register' успешно завершена;")
#     except Exception as e:
#         error_message: str = "Ошибка выполнения в функции 'swap_register';"
#         logger.error(error_message)
# Out:
# 2024-08-04 01:22:19.036 | INFO     | __main__:<module>:28 - Запуск функции 'swap_register';
# 2024-08-04 01:22:19.038 | DEBUG    | __main__:swap_register:2 - string='some text': <class 'str'>
# 2024-08-04 01:22:19.039 | INFO     | __main__:<module>:30 - Функция 'swap_register' успешно завершена;
# SOME TEXT
# ======================================= test session starts ========================================
# platform darwin -- Python 3.12.4, pytest-8.3.2, pluggy-1.5.0
# rootdir: /Users/dmitrijkolganov/Yandex.Disk.localized/git/education/stepik.org/artyom_egorov/01_course_python_indie/modules/02. Строки и списки
# collected 3 items
#
# t_0c063925ecbb4899af65306f355a1cba.py
# 2024-08-04 01:22:19.071 | DEBUG    | __main__:swap_register:2 - string='test_string': <class 'str'>
# .
# 2024-08-04 01:22:19.074 | DEBUG    | __main__:swap_register:2 - string='прогРаммирОВАНИЕ': <class 'str'>
# .
# ...

# %% [markdown]
# # Step 8

# %%
# %%ipytest -v
#
# def title_and_swap_register(string: str) -> str:
#     logger.debug(f"{string=}: {type(string)}")
#
#     # Проверка типа переданного аргумента;
#     if not isinstance(string, str):
#         error_message: str = "Некорректный тип данных;"
#         logger.error(error_message)
#         raise TypeError(error_message)
#
#     return string.title().swapcase()
#
# @pytest.mark.parametrize(
#     ["test_string", "expected_result"],
#     [
#         ("Every You Every Me", "eVERY yOU eVERY mE"),
#         ("RunnING up That HILL", "rUNNING uP tHAT hILL"),
#         ("Sleeping with GHOSTS", "sLEEPING wITH gHOSTS")
#     ]
# )
# def test_title_and_swap_register(
#         test_string: str,
#         expected_result: str,
# ) -> None:
#     assert title_and_swap_register(string=test_string) == expected_result
#
# if __name__ == "__main__":
#     try:
#         logger.info("Запуск функции 'title_and_swap_register';")
#         print(title_and_swap_register(string="some text"))
#         logger.info("Функция 'title_and_swap_register' успешно завершена;")
#     except Exception as e:
#         error_message: str = "Ошибка выполнения в функции 'title_and_swap_register';"
#         logger.error(error_message)
# Out:
# 2024-08-04 01:22:19.092 | INFO     | __main__:<module>:28 - Запуск функции 'title_and_swap_register';
# 2024-08-04 01:22:19.094 | DEBUG    | __main__:title_and_swap_register:2 - string='some text': <class 'str'>
# 2024-08-04 01:22:19.095 | INFO     | __main__:<module>:30 - Функция 'title_and_swap_register' успешно завершена;
# sOME tEXT
# ======================================= test session starts ========================================
# platform darwin -- Python 3.12.4, pytest-8.3.2, pluggy-1.5.0
# rootdir: /Users/dmitrijkolganov/Yandex.Disk.localized/git/education/stepik.org/artyom_egorov/01_course_python_indie/modules/02. Строки и списки
# collected 3 items
#
# t_0c063925ecbb4899af65306f355a1cba.py
# 2024-08-04 01:22:19.154 | DEBUG    | __main__:title_and_swap_register:2 - string='Every You Every Me': <class 'str'>
# .
# 2024-08-04 01:22:19.157 | DEBUG    | __main__:title_and_swap_register:2 - string='RunnING up That HILL': <class 'str'>
# .
# ...

# %% [markdown]
# # Step 9

# %%
# %%ipytest -v
#
# def count_char_e(string: str) -> int:
#     logger.debug(f"{string=}: {type(string)}")
#
#     # Проверка типа переданного аргумента;
#     if not isinstance(string, str):
#         error_message: str = "Некорректный тип данных;"
#         logger.error(error_message)
#         raise TypeError(error_message)
#
#     return string.lower().count("e")
#
# @pytest.mark.parametrize(
#     ["test_string", "expected_result"],
#     [
#         ("test string", 1),
#         ("Helen", 2),
#         ("EveryWHERE", 4)
#     ]
# )
# def test_count_char_e(
#         test_string: str,
#         expected_result: int,
# ) -> None:
#     assert count_char_e(string=test_string) == expected_result
#
# if __name__ == "__main__":
#     try:
#         logger.info("Запуск функции 'count_char_e';")
#         print(count_char_e(string="some text"))
#         logger.info("Функция 'count_char_e' успешно завершена;")
#     except Exception as e:
#         error_message: str = "Ошибка выполнения в функции 'count_char_e';"
#         logger.error(error_message)
# Out:
# 2024-08-04 01:22:19.175 | INFO     | __main__:<module>:28 - Запуск функции 'count_char_e';
# 2024-08-04 01:22:19.177 | DEBUG    | __main__:count_char_e:2 - string='some text': <class 'str'>
# 2024-08-04 01:22:19.179 | INFO     | __main__:<module>:30 - Функция 'count_char_e' успешно завершена;
# 2
# ======================================= test session starts ========================================
# platform darwin -- Python 3.12.4, pytest-8.3.2, pluggy-1.5.0
# rootdir: /Users/dmitrijkolganov/Yandex.Disk.localized/git/education/stepik.org/artyom_egorov/01_course_python_indie/modules/02. Строки и списки
# collected 3 items
#
# t_0c063925ecbb4899af65306f355a1cba.py
# 2024-08-04 01:22:19.213 | DEBUG    | __main__:count_char_e:2 - string='test string': <class 'str'>
# .
# 2024-08-04 01:22:19.216 | DEBUG    | __main__:count_char_e:2 - string='Helen': <class 'str'>
# .
# 2024-08-04 01:22:19.218 | DEBUG    | __main__:count_char_e:2 - string='EveryWHERE': <class 'str'>
# ...

# %% [markdown]
# # Step 12

# %%
# %%ipytest -v
#
# def index_first_char_a(string: str) -> int:
#     logger.debug(f"{string=}: {type(string)}")
#
#     # Проверка типа переданного аргумента;
#     if not isinstance(string, str):
#         error_message: str = "Неправильный тип данных;"
#         logger.error(error_message)
#         raise TypeError(error_message)
#
#     return string.lower().find("a")
#
# @pytest.mark.parametrize(
#     ["test_string", "expected_result"],
#     [
#         # Good cases
#         ("Alphabet", 0),
#         ("avadacedavra", 0),
#         ("test string without ch_r", -1),
#
#         # Edge cases
#         ("A", 0),
#         ("", -1),
#         ("test ch_r 'а' in other l_ngu_ge", -1),
#
#         # Error cases
#         (123, TypeError),
#         (None, TypeError),
#     ]
# )
# def test_index_first_char_b(
#         test_string: str,
#         expected_result
# ) -> None:
#     if test_string in {123, None}:
#         with pytest.raises(TypeError):
#             index_first_char_a(string=test_string)
#
#     else:
#         assert index_first_char_a(string=test_string) == expected_result
#
# if __name__ == "__main__":
#     try:
#         logger.info("Запуск функции 'index_first_char_a';")
#         print(index_first_char_a(string="test string with char a"))
#         logger.info("Функция 'index_first_char_a' успешно завершена;")
#     except Exception as e:
#         error_message: str = "Ошибка выполнения в функции 'index_first_char_a';"
#         logger.error(error_message)
# Out:
# 2024-08-04 01:22:19.237 | INFO     | __main__:<module>:43 - Запуск функции 'index_first_char_a';
# 2024-08-04 01:22:19.239 | DEBUG    | __main__:index_first_char_a:2 - string='test string with char a': <class 'str'>
# 19
# 2024-08-04 01:22:19.240 | INFO     | __main__:<module>:45 - Функция 'index_first_char_a' успешно завершена;
# ======================================= test session starts ========================================
# platform darwin -- Python 3.12.4, pytest-8.3.2, pluggy-1.5.0
# rootdir: /Users/dmitrijkolganov/Yandex.Disk.localized/git/education/stepik.org/artyom_egorov/01_course_python_indie/modules/02. Строки и списки
# collected 8 items
#
# t_0c063925ecbb4899af65306f355a1cba.py
# 2024-08-04 01:22:19.276 | DEBUG    | __main__:index_first_char_a:2 - string='Alphabet': <class 'str'>
# .
# 2024-08-04 01:22:19.280 | DEBUG    | __main__:index_first_char_a:2 - string='avadacedavra': <class 'str'>
# .
# ...

# %% [markdown]
# # Step 13

# %%
# %%ipytest -v
#
# def index_last_char_a(string: str) -> int:
#     logger.debug(f"{string=}: {type(string)}")
#
#     # Проверка типа переданного аргумента;
#     if not isinstance(string, str):
#         error_message: str = "Неправильный тип данных;"
#         logger.error(error_message)
#         raise TypeError(error_message)
#
#     return string.rfind("a")
#
# @pytest.mark.parametrize(
#     ["test_string", "expected_result"],
#     [
#         # Good cases
#         ("Alphabet", 4),
#         ("avadacedavra", 11),
#         ("test string without ch_r", -1),
#
#         # Edge cases
#         ("A", -1),
#         ("", -1),
#         ("test ch_r 'а' in other l_ngu_ge", -1),
#
#         # Error cases
#         (123, TypeError),
#         (None, TypeError),
#     ]
# )
# def test_index_last_char_a(
#         test_string: str,
#         expected_result
# ) -> None:
#     if test_string in {123, None}:
#         with pytest.raises(TypeError):
#             index_last_char_a(string=test_string)
#
#     else:
#         assert index_last_char_a(string=test_string) == expected_result
#
# if __name__ == "__main__":
#     try:
#         logger.info("Запуск функции 'index_last_char_a';")
#         print(index_last_char_a(string="banana"))
#         logger.info("Функция 'index_first_char_a' успешно завершена;")
#     except Exception as e:
#         error_message: str = "Ошибка выполнения в функции 'index_last_char_a';"
#         logger.error(error_message)
# Out:
# 2024-08-04 01:22:19.323 | INFO     | __main__:<module>:43 - Запуск функции 'index_last_char_a';
# 2024-08-04 01:22:19.325 | DEBUG    | __main__:index_last_char_a:2 - string='banana': <class 'str'>
# 2024-08-04 01:22:19.329 | INFO     | __main__:<module>:45 - Функция 'index_first_char_a' успешно завершена;
# 5
# ======================================= test session starts ========================================
# platform darwin -- Python 3.12.4, pytest-8.3.2, pluggy-1.5.0
# rootdir: /Users/dmitrijkolganov/Yandex.Disk.localized/git/education/stepik.org/artyom_egorov/01_course_python_indie/modules/02. Строки и списки
# collected 8 items
#
# t_0c063925ecbb4899af65306f355a1cba.py
# 2024-08-04 01:22:19.366 | DEBUG    | __main__:index_last_char_a:2 - string='Alphabet': <class 'str'>
# .
# 2024-08-04 01:22:19.370 | DEBUG    | __main__:index_last_char_a:2 - string='avadacedavra': <class 'str'>
# .
# ...

# %% [markdown]
# # Step 14

# %%
# %%ipytest -v
#
# def space_to_coma(string: str) -> str:
#     logger.debug(f"{string=}: {type(string)}")
#
#     # Проверка типа переданного аргумента;
#     if not isinstance(string, str):
#         error_message: str = "Неправильный тип данных;"
#         logger.error(error_message)
#         raise TypeError(error_message)
#
#     return string.replace(" ", ",")
#
# @pytest.mark.parametrize(
#     ["test_string", "expected_result"],
#     [
#         # Good cases
#         ("hello world", "hello,world"),
#         ("a b c", "a,b,c"),
#         ("", ""),
#         ("no_spaces", "no_spaces"),
#
#         # Edge cases
#         (" ", ","),
#         ("   ", ",,,"),
#         (" leading space", ",leading,space"),
#         ("trailing space ", "trailing,space,"),
#         (" multiple   spaces ", ",multiple,,,spaces,"),
#
#         # Error cases
#         (123, TypeError),
#         (None, TypeError),
#     ]
# )
# def test_space_to_coma(
#         test_string: str,
#         expected_result
# ) -> None:
#     if test_string in {123, None}:
#         with pytest.raises(TypeError):
#             space_to_coma(test_string)
#     else:
#         assert space_to_coma(string=test_string) == expected_result
#
# if __name__ == "__main__":
#     try:
#         logger.info("Запуск функции 'space_to_coma';")
#         print(space_to_coma(string="hello world"))
#         logger.info("Функция 'space_to_coma' успешно завершена;")
#     except Exception as e:
#         error_message: str = "Ошибка выполнения в функции 'space_to_coma';"
#         logger.error(error_message)
# Out:
# 2024-08-04 01:22:19.418 | INFO     | __main__:<module>:45 - Запуск функции 'space_to_coma';
# 2024-08-04 01:22:19.419 | DEBUG    | __main__:space_to_coma:2 - string='hello world': <class 'str'>
# 2024-08-04 01:22:19.420 | INFO     | __main__:<module>:47 - Функция 'space_to_coma' успешно завершена;
# hello,world
# ======================================= test session starts ========================================
# platform darwin -- Python 3.12.4, pytest-8.3.2, pluggy-1.5.0
# rootdir: /Users/dmitrijkolganov/Yandex.Disk.localized/git/education/stepik.org/artyom_egorov/01_course_python_indie/modules/02. Строки и списки
# collected 11 items
#
# t_0c063925ecbb4899af65306f355a1cba.py
# 2024-08-04 01:22:19.472 | DEBUG    | __main__:space_to_coma:2 - string='hello world': <class 'str'>
# .
# 2024-08-04 01:22:19.477 | DEBUG    | __main__:space_to_coma:2 - string='a b c': <class 'str'>
# .
# 2024-08-04 01:22:19.481 | DEBUG    | __main__:space_to_coma:2 - string='': <class 'str'>
# .
# ...

# %% [markdown]
# # Step 15

# %%
# %%ipytest -v
#
# def del_chars_w_z(string: str) -> str:
#     logger.debug(f"{string=}: {type(string)}")
#
#     # Проверка типа переданного аргумента;
#     if not isinstance(string, str):
#         error_message: str = "Неправильный тип данных;"
#         logger.error(error_message)
#         raise TypeError(error_message)
#
#     return (
#         string
#         .replace("w", "")
#         .replace("z", "")
#     )
#
# @pytest.mark.parametrize(
#     ["test_string", "expected_result"],
#     [
#         # Good cases
#         ("wizard", "iard"),
#         ("wow", "o"),
#         ("buzz", "bu"),
#         ("no_w_or_z", "no__or_"),
#
#         # Edge cases
#         ("w", ""),
#         ("z", ""),
#         ("wz", ""),
#         ("", ""),
#
#         # Error cases
#         (123, TypeError),
#         (None, TypeError),
#     ]
# )
# def test_del_chars_w_z(
#         test_string: str,
#         expected_result
# ) -> None:
#     if test_string in {123, None}:
#         with pytest.raises(TypeError):
#             del_chars_w_z(test_string)
#     else:
#         assert del_chars_w_z(string=test_string) == expected_result
#
# if __name__ == "__main__":
#     try:
#         logger.info("Запуск функции 'del_chars_w_z';")
#         print(del_chars_w_z(string="wizard"))
#         logger.info("Функция 'del_chars_w_z' успешно завершена;")
#     except Exception as e:
#         error_message: str = "Ошибка выполнения в функции 'del_chars_w_z';"
#         logger.error(error_message)
# Out:
# 2024-08-04 01:22:19.535 | INFO     | __main__:<module>:48 - Запуск функции 'del_chars_w_z';
# 2024-08-04 01:22:19.537 | DEBUG    | __main__:del_chars_w_z:2 - string='wizard': <class 'str'>
# 2024-08-04 01:22:19.540 | INFO     | __main__:<module>:50 - Функция 'del_chars_w_z' успешно завершена;
# iard
# ======================================= test session starts ========================================
# platform darwin -- Python 3.12.4, pytest-8.3.2, pluggy-1.5.0
# rootdir: /Users/dmitrijkolganov/Yandex.Disk.localized/git/education/stepik.org/artyom_egorov/01_course_python_indie/modules/02. Строки и списки
# collected 10 items
#
# t_0c063925ecbb4899af65306f355a1cba.py
# 2024-08-04 01:22:19.620 | DEBUG    | __main__:del_chars_w_z:2 - string='wizard': <class 'str'>
# .
# 2024-08-04 01:22:19.625 | DEBUG    | __main__:del_chars_w_z:2 - string='wow': <class 'str'>
# .
# 2024-08-04 01:22:19.628 | DEBUG    | __main__:del_chars_w_z:2 - string='buzz': <class 'str'>
# .
# ...

# %% [markdown]
# # Step 16

# %%
# %%ipytest -v
#
# def why_i_should_do_this(string: str) -> str:
#     logger.debug(f"{string=}: {type(string)}")
#
#     # Проверка типа переданного аргумента;
#     if not isinstance(string, str):
#         error_message: str = "Неправильный тип данных;"
#         logger.error(error_message)
#         raise TypeError(error_message)
#
#     for char in "aeyiou":
#         string = string.lower().replace(char, "")
#
#     return "." + ".".join(string.lower()) if len(string) > 0 else string.lower()
#
# @pytest.mark.parametrize(
#     ["test_string", "expected_result"],
#     [
#         # Good cases
#         ("hello", ".h.l.l"),
#         ("bcdfghjklmnpqrstvwxyz", ".b.c.d.f.g.h.j.k.l.m.n.p.q.r.s.t.v.w.x.z"),
#
#         # Edge Cases
#         ("aeyiou", ""),
#         ("", ""),
#
#         # Error cases
#         (123, TypeError),
#         (None, TypeError),
#     ]
# )
# def test_why_i_should_do_this(test_string: str, expected_result) -> None:
#     if test_string in {123, None}:
#         with pytest.raises(TypeError):
#             why_i_should_do_this(test_string)
#     else:
#         assert why_i_should_do_this(string=test_string) == expected_result
#
# if __name__ == "__main__":
#     try:
#         logger.info("Запуск функции 'why_i_should_do_this';")
#         print(why_i_should_do_this(string="this is test string"))
#         logger.info("Функция 'why_i_should_do_this' успешно завершена;")
#     except Exception as e:
#         error_message: str = "Ошибка выполнения в функции 'why_i_should_do_this';"
#         logger.error(error_message)
# Out:
# 2024-08-04 01:22:19.675 | INFO     | __main__:<module>:40 - Запуск функции 'why_i_should_do_this';
# 2024-08-04 01:22:19.677 | DEBUG    | __main__:why_i_should_do_this:2 - string='this is test string': <class 'str'>
# 2024-08-04 01:22:19.677 | INFO     | __main__:<module>:42 - Функция 'why_i_should_do_this' успешно завершена;
# .t.h.s. .s. .t.s.t. .s.t.r.n.g
# ======================================= test session starts ========================================
# platform darwin -- Python 3.12.4, pytest-8.3.2, pluggy-1.5.0
# rootdir: /Users/dmitrijkolganov/Yandex.Disk.localized/git/education/stepik.org/artyom_egorov/01_course_python_indie/modules/02. Строки и списки
# collected 6 items
#
# t_0c063925ecbb4899af65306f355a1cba.py
# 2024-08-04 01:22:19.737 | DEBUG    | __main__:why_i_should_do_this:2 - string='hello': <class 'str'>
# .
# 2024-08-04 01:22:19.743 | DEBUG    | __main__:why_i_should_do_this:2 - string='bcdfghjklmnpqrstvwxyz': <class 'str'>
# .
# ...
