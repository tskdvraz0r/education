# %%
import pytest
import ipytest
from loguru import logger

# %%
ipytest.autoconfig()

logger.add(
    sink='../../logs/logs.json',
    format='{time} {level} {message}',
    level='DEBUG',
    rotation='1 Mb',
    retention='1 day',
    compression='zip',
    backtrace=True,
    diagnose=True,
    enqueue=True,
    serialize=True,
    catch=True,
    colorize=True
)
# Out:
# 1

# %% [markdown]
# # Step 3

# %%
# %%ipytest
#
# @logger.catch()
# def first_element(string: str) -> str:
#     if not isinstance(string, str):
#         error_msg: str = "Некорректный тип данных;"
#         logger.error(error_msg)
#         raise TypeError(error_msg)
#
#     return string[0]
#
# @logger.catch()
# @pytest.mark.parametrize(
#     ["test_string", "expected_result"],
#     [
#         ("String", "S"),
#         ("Test", "T"),
#         ("Python", "P")
#     ]
# )
# def test_first_element(
#         test_string: str,
#         expected_result: str
# ) -> None:
#     assert first_element(string=test_string) == expected_result
#
# if __name__ == "__main__":
#     try:
#         logger.info("Вызов функции 'first_element';")
#         print(first_element(string="МФТИ"))
#         logger.info("Успешное завершение функции 'first_element';")
#
#     except Exception as err:
#         logger.error("Ошибка выполнения функции 'first_element';")
# Out:
# 2024-08-01 23:57:09.238 | INFO     | __main__:<module>:27 - Вызов функции 'first_element';
# 2024-08-01 23:57:09.241 | INFO     | __main__:<module>:29 - Успешное завершение функции 'first_element';
# М
# ...                                                                                          [100%]
# 3 passed in 0.01s
# ..                                                                                          [100%]
# 3 passed in 0.01s

# %% [markdown]
# # Step 7

# %%
# %%ipytest
#
# @logger.catch()
# def last_element(string: str) -> str:
#     if not isinstance(string, str):
#         error_msg: str = "Некорректный тип данных;"
#         logger.error(error_msg)
#         raise TypeError(error_msg)
#
#     return string[-1]
#
# @logger.catch()
# @pytest.mark.parametrize(
#     ["test_string", "expected_result"],
#     [
#         ("String", "g"),
#         ("Test", "t"),
#         ("Python", "n")
#     ]
# )
# def test_last_element(
#         test_string: str,
#         expected_result: str
# ) -> None:
#     assert last_element(string=test_string) == expected_result
#
# if __name__ == "__main__":
#     try:
#         logger.info("Вызов функции 'last_element';")
#         print(last_element(string="МФТИ"))
#         logger.info("Успешное завершение функции 'last_element';")
#
#     except Exception as err:
#         logger.error("Ошибка выполнения функции 'last_element';")
# Out:
# 2024-08-01 23:57:09.325 | INFO     | __main__:<module>:27 - Вызов функции 'last_element';
# 2024-08-01 23:57:09.326 | INFO     | __main__:<module>:29 - Успешное завершение функции 'last_element';
# И
# ...                                                                                          [100%]
# 3 passed in 0.01s
# ..                                                                                          [100%]
# 3 passed in 0.01s

# %% [markdown]
# # Step 8

# %%
# %%ipytest
#
# @logger.catch()
# def first_four_elements(string: str) -> str:
#     if not isinstance(string, str):
#         error_msg: str = "Некорректный тип данных;"
#         logger.error(error_msg)
#         raise TypeError(error_msg)
#
#     return string[:4]
#
# @logger.catch()
# @pytest.mark.parametrize(
#     ["test_string", "expected_result"],
#     [
#         ("String", "Stri"),
#         ("Test", "Test"),
#         ("Python", "Pyth")
#     ]
# )
# def test_first_four_elements(
#         test_string: str,
#         expected_result: str
# ) -> None:
#     assert first_four_elements(string=test_string) == expected_result
#
# if __name__ == "__main__":
#     try:
#         logger.info("Вызов функции 'first_four_elements';")
#         print(first_four_elements(string="МФТИ"))
#         logger.info("Успешное завершение функции 'first_four_elements';")
#
#     except Exception as err:
#         logger.error("Ошибка выполнения функции 'first_four_elements';")
# Out:
# 2024-08-01 23:57:09.371 | INFO     | __main__:<module>:27 - Вызов функции 'first_four_elements';
# 2024-08-01 23:57:09.372 | INFO     | __main__:<module>:29 - Успешное завершение функции 'first_four_elements';
# МФТИ
# ...                                                                                          [100%]
# 3 passed in 0.01s
# ..                                                                                          [100%]
# 3 passed in 0.01s

# %% [markdown]
# # Step 9

# %%
# %%ipytest
#
# @logger.catch()
# def last_four_elements(string: str) -> str:
#     if not isinstance(string, str):
#         error_msg: str = "Некорректный тип данных;"
#         logger.error(error_msg)
#         raise TypeError(error_msg)
#
#     return string[-4:]
#
# @logger.catch()
# @pytest.mark.parametrize(
#     ["test_string", "expected_result"],
#     [
#         ("String", "ring"),
#         ("Test", "Test"),
#         ("Python", "thon")
#     ]
# )
# def test_last_four_elements(
#         test_string: str,
#         expected_result: str
# ) -> None:
#     assert last_four_elements(string=test_string) == expected_result
#
# if __name__ == "__main__":
#     try:
#         logger.info("Вызов функции 'last_four_elements';")
#         print(last_four_elements(string="МФТИ"))
#         logger.info("Успешное завершение функции 'last_four_elements';")
#
#     except Exception as err:
#         logger.error("Ошибка выполнения функции 'last_four_elements';")
# Out:
# 2024-08-01 23:57:09.408 | INFO     | __main__:<module>:27 - Вызов функции 'last_four_elements';
# 2024-08-01 23:57:09.409 | INFO     | __main__:<module>:29 - Успешное завершение функции 'last_four_elements';
# МФТИ
# ...                                                                                          [100%]
# 3 passed in 0.01s
# ..                                                                                          [100%]
# 3 passed in 0.01s

# %% [markdown]
# # Step 10

# %%
# %%ipytest
#
# @logger.catch()
# def even_elements(string: str) -> str:
#     if not isinstance(string, str):
#         error_msg: str = "Некорректный тип данных;"
#         logger.error(error_msg)
#         raise TypeError(error_msg)
#
#     return string[::2]
#
# @logger.catch()
# @pytest.mark.parametrize(
#     ["test_string", "expected_result"],
#     [
#         ("String", "Srn"),
#         ("Test", "Ts"),
#         ("Python", "Pto")
#     ]
# )
# def test_even_elements(
#         test_string: str,
#         expected_result: str
# ) -> None:
#     assert even_elements(string=test_string) == expected_result
#
# if __name__ == "__main__":
#     try:
#         logger.info("Вызов функции 'even_elements';")
#         print(even_elements(string="МФТИ"))
#         logger.info("Успешное завершение функции 'even_elements';")
#
#     except Exception as err:
#         logger.error("Ошибка выполнения функции 'even_elements';")
# Out:
# 2024-08-01 23:57:09.446 | INFO     | __main__:<module>:27 - Вызов функции 'even_elements';
# 2024-08-01 23:57:09.447 | INFO     | __main__:<module>:29 - Успешное завершение функции 'even_elements';
# МТ
# ...                                                                                          [100%]
# 3 passed in 0.01s
# ..                                                                                          [100%]
# 3 passed in 0.01s

# %% [markdown]
# # Step 11

# %%
# %%ipytest
#
# @logger.catch()
# def odd_elements(string: str) -> str:
#     if not isinstance(string, str):
#         error_msg: str = "Некорректный тип данных;"
#         logger.error(error_msg)
#         raise TypeError(error_msg)
#
#     return string[1::2]
#
# @logger.catch()
# @pytest.mark.parametrize(
#     ["test_string", "expected_result"],
#     [
#         ("String", "tig"),
#         ("Test", "et"),
#         ("Python", "yhn")
#     ]
# )
# def test_odd_elements(
#         test_string: str,
#         expected_result: str
# ) -> None:
#     assert odd_elements(string=test_string) == expected_result
#
# if __name__ == "__main__":
#     try:
#         logger.info("Вызов функции 'odd_elements';")
#         print(odd_elements(string="МФТИ"))
#         logger.info("Успешное завершение функции 'odd_elements';")
#
#     except Exception as err:
#         logger.error("Ошибка выполнения функции 'odd_elements';")
# Out:
# 2024-08-01 23:57:09.486 | INFO     | __main__:<module>:27 - Вызов функции 'odd_elements';
# 2024-08-01 23:57:09.487 | INFO     | __main__:<module>:29 - Успешное завершение функции 'odd_elements';
# ФИ
# ...                                                                                          [100%]
# 3 passed in 0.01s

# %% [markdown]
# # Step 12

# %%
# %%ipytest
#
# @logger.catch()
# def reverse_string(string: str) -> str:
#     if not isinstance(string, str):
#         error_msg: str = "Некорректный тип данных;"
#         logger.error(error_msg)
#         raise TypeError(error_msg)
#
#     return string[::-1]
#
# @logger.catch()
# @pytest.mark.parametrize(
#     ["test_string", "expected_result"],
#     [
#         ("String", "gnirtS"),
#         ("Test", "tseT"),
#         ("Python", "nohtyP")
#     ]
# )
# def test_reverse_string(
#         test_string: str,
#         expected_result: str
# ) -> None:
#     assert reverse_string(string=test_string) == expected_result
#
# if __name__ == "__main__":
#     try:
#         logger.info("Вызов функции 'reverse_string';")
#         print(reverse_string(string="МФТИ"))
#         logger.info("Успешное завершение функции 'reverse_string';")
#
#     except Exception as err:
#         logger.error("Ошибка выполнения функции 'reverse_string';")
# Out:
# 2024-08-01 23:57:09.523 | INFO     | __main__:<module>:27 - Вызов функции 'reverse_string';
# 2024-08-01 23:57:09.524 | INFO     | __main__:<module>:29 - Успешное завершение функции 'reverse_string';
# ИТФМ
# ...                                                                                          [100%]
# 3 passed in 0.01s

# %% [markdown]
# # Step 13

# %%
# %%ipytest
#
# @logger.catch()
# def reverse_each_third_element(string: str) -> str:
#     if not isinstance(string, str):
#         error_msg: str = "Некорректный тип данных;"
#         logger.error(error_msg)
#         raise TypeError(error_msg)
#
#     return string[::-3]
#
# @logger.catch()
# @pytest.mark.parametrize(
#     ["test_string", "expected_result"],
#     [
#         ("StringString", "grgr"),
#         ("TestTest", "tTe"),
#         ("PythonPython", "ntnt")
#     ]
# )
# def test_reverse_each_third_element(
#         test_string: str,
#         expected_result: str
# ) -> None:
#     assert reverse_each_third_element(string=test_string) == expected_result
#
# if __name__ == "__main__":
#     try:
#         logger.info("Вызов функции 'reverse_each_third_element';")
#         print(reverse_each_third_element(string="Московский физико-технический институт"))
#         logger.info("Успешное завершение функции 'reverse_each_third_element';")
#
#     except Exception as err:
#         logger.error("Ошибка выполнения функции 'reverse_each_third_element';")
# Out:
# 2024-08-01 23:57:09.585 | INFO     | __main__:<module>:27 - Вызов функции 'reverse_each_third_element';
# 2024-08-01 23:57:09.586 | INFO     | __main__:<module>:29 - Успешное завершение функции 'reverse_each_third_element';
# тинйсиеоз коо
# ...                                                                                          [100%]
# 3 passed in 0.01s

# %% [markdown]
# # Step 14

# %%
# %%ipytest
#
# @logger.catch()
# def last_element_to_start(string: str) -> str:
#     if not isinstance(string, str):
#         error_msg: str = "Некорректный тип данных;"
#         logger.error(error_msg)
#         raise TypeError(error_msg)
#
#     return string[-1] + string[:-1]
#
# @logger.catch()
# @pytest.mark.parametrize(
#     ["test_string", "expected_result"],
#     [
#         ("String", "gStrin"),
#         ("Test", "tTes"),
#         ("Python", "nPytho")
#     ]
# )
# def test_last_element_to_start(
#         test_string: str,
#         expected_result: str
# ) -> None:
#     assert last_element_to_start(string=test_string) == expected_result
#
# if __name__ == "__main__":
#     try:
#         logger.info("Вызов функции 'last_element_to_start';")
#         print(last_element_to_start(string="The Big Bang Theory"))
#         logger.info("Успешное завершение функции 'last_element_to_start';")
#
#     except Exception as err:
#         logger.error("Ошибка выполнения функции 'last_element_to_start';")
# Out:
# 2024-08-01 23:57:09.628 | INFO     | __main__:<module>:27 - Вызов функции 'last_element_to_start';
# 2024-08-01 23:57:09.630 | INFO     | __main__:<module>:29 - Успешное завершение функции 'last_element_to_start';
# yThe Big Bang Theor
# ...                                                                                          [100%]
# 3 passed in 0.01s
