# %% [markdown]
# # IMPORTS

# %% [markdown]
# # 6.1 Типы данных list и tuple

# %% [markdown]
# # 6.2 Типы данных set и dict

# %% [markdown]
# # 6.3 Тип данных namedtuple. Часть 1

# %% [markdown]
# # 6.4 Тип данных namedtuple. Часть 2

# %% [markdown]
# # 6.5 Тип данных defaultdict

# %% [markdown]
# # 6.6 Тип данных OrderedDict

# %% [markdown]
# # 6.7 Тип данных Counter. Часть 1

# %% [markdown]
# # 6.8 Тип данных Counter. Часть 2

# %% [markdown]
# # 6.9 Тип данных ChainMap. Часть 1

# %% [markdown]
# # 6.10 Тип данных ChainMap. Часть 2

# %% [markdown]
# # 6.11 Материал для самостоятельного изучения
