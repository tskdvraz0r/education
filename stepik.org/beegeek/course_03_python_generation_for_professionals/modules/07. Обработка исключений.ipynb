# %% [markdown]
# # IMPORTS

# %% [markdown]
# # 7.1 Обработка исключений. Часть 1

# %% [markdown]
# # 7.2 Обработка исключений. Часть 2

# %% [markdown]
# # 7.3 Обработка исключений. Часть 3

# %% [markdown]
# # 7.4 Обработка исключений. Часть 4

# %% [markdown]
# # 7.5 Обработка исключений. Часть 5
