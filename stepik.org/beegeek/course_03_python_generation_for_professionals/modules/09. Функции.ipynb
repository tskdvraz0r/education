# %% [markdown]
# # IMPORTS

# %% [markdown]
# # 9.1 Встроенные функции. Часть 1

# %% [markdown]
# # 9.2 Встроенные функции. Часть 2

# %% [markdown]
# # 9.3 Функции высшего порядка map(), filter(). Анонимные функции

# %% [markdown]
# # 9.4 Функции как объекты

# %% [markdown]
# # 9.5 Вложенные функции, замыкания

# %% [markdown]
# # 9.6 Аннотации типов

# %% [markdown]
# # 9.7 Декораторы. Часть 1

# %% [markdown]
# # 9.8 Декораторы. Часть 2

# %% [markdown]
# # 9.9 Модуль functools
