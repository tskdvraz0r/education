# %% [markdown]
# # IMPORTS

# %% [markdown]
# # 11.1 Регулярные выражения. Часть 1

# %% [markdown]
# # 11.2 Регулярные выражения. Часть 2

# %% [markdown]
# # 11.3 Регулярные выражения. Часть 3

# %% [markdown]
# # 11.4 Регулярные выражения. Часть 4

# %% [markdown]
# # 11.5 Регулярные выражения. Часть 5

# %% [markdown]
# # 11.6 Модуль re. Часть 1

# %% [markdown]
# # 11.7 Модуль re. Часть 2

# %% [markdown]
# # 11.8 Модуль re. Часть 3

# %% [markdown]
# # 11.9 Модуль re. Часть 4
