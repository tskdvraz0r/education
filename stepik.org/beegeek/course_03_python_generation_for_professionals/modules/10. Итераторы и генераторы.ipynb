# %% [markdown]
# # IMPORTS

# %% [markdown]
# # 10.1 Итераторы. Часть 1

# %% [markdown]
# # 10.2 Итераторы. Часть 2

# %% [markdown]
# # 10.3 Итераторы. Часть 3

# %% [markdown]
# # 10.4 Итераторы. Часть 4

# %% [markdown]
# # 10.5 Генераторы. Часть 1

# %% [markdown]
# # 10.6 Генераторы. Часть 2

# %% [markdown]
# # 10.7 Генераторы. Часть 3

# %% [markdown]
# # 10.8 Модуль itertools. Часть 1

# %% [markdown]
# # 10.9 Модуль itertools. Часть 2

# %% [markdown]
# # 10.10 Модуль itertools. Часть 3

# %% [markdown]
# # 10.11 Модуль itertools. Часть 4

# %% [markdown]
# # 10.12 Модуль itertools. Часть 5
