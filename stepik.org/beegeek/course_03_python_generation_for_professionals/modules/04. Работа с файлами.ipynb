# %% [markdown]
# # IMPORTS

# %% [markdown]
# # 4.1 Потоковый ввод stdin и вывод stdout

# %% [markdown]
# # 4.2 Работа с csv файлами

# %% [markdown]
# # 4.3 Работа с json файлами. Часть 1

# %% [markdown]
# # 4.4 Работа с json файлами. Часть 2

# %% [markdown]
# # 4.5 Работа с zip файлами

# %% [markdown]
# # 4.6 Работа с pickle файлами

# %% [markdown]
# # 4.7 Материал для самостоятельного изучения
