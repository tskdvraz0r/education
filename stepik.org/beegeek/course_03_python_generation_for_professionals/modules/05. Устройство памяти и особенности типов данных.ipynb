# %% [markdown]
# # IMPORTS

# %% [markdown]
# # 5.1 Устройство памяти в Python

# %% [markdown]
# # 5.2 Работа переменных в Python

# %% [markdown]
# # 5.3 Изменяемые и неизменяемые типы

# %% [markdown]
# # 5.4 Поверхностное и глубокое копирование объектов

# %% [markdown]
# # 5.5 Механизмы очистки памяти
