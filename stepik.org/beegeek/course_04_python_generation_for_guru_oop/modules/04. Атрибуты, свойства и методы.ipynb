# %% [markdown]
# # IMPORTS

# %%
import math

# %% [markdown]
# # 4.1 Атрибуты объектов и классов

# %%
# Date: 27.01.2024
# Step: 4.1.18
# Url: https://stepik.org/lesson/788965/step/18?unit=791610

class PiggyBank:
    pass

money_box: PiggyBank = PiggyBank()

# %%
# Date: 27.01.2024
# Step: 4.1.19
# Url: https://stepik.org/lesson/788965/step/19?unit=791610

class PiggyBank:
    pass

money_box1: PiggyBank = PiggyBank()
money_box2: PiggyBank = PiggyBank()

money_box1.coins = 10
money_box2.coins = 15
money_box2.color = "pink"

# %%
# Date: 27.01.2024
# Step: 4.1.20
# Url: https://stepik.org/lesson/788965/step/20?unit=791610

class PiggyBank:
    content: str = "coins"
    alternate_name: str = "penny bank"

money_box: PiggyBank = PiggyBank()

# %% [markdown]
# # 4.2 Методы экземпляра класса. Часть 1

# %%
# None

# %% [markdown]
# # 4.3 Методы экземпляра класса. Часть 2

# %%
# Date: 28.01.2024
# Step: 4.3.2
# Url: https://stepik.org/lesson/794582/step/2?unit=797335

class Gun:
    def shoot(self):
        print("pif")

# %%
# Date: 28.01.2024
# Step: 4.3.3
# Url: https://stepik.org/lesson/794582/step/3?unit=797335

class User:
    def __init__(self, name: str, friends: int = 0):
        self.name = name,
        self.friends = friends
    
    def add_friends(self, n):
        self.friends += n

# %%
# Date: 28.01.2024
# Step: 4.3.4
# Url: https://stepik.org/lesson/794582/step/4?unit=797335

class House:
    def __init__(self, color: str, rooms: int):
        self.color = color
        self.rooms = rooms
    
    def paint(self, new_color: str):
        self.color = new_color
    
    def add_rooms(self, n: int):
        self.rooms += n

# %%
# Date: 28.01.2024
# Step: 4.3.5
# Url: https://stepik.org/lesson/794582/step/5?unit=797335

class Circle:
    def __init__(self, radius: int):
        self.radius = radius
        self.diameter = radius * 2
        self.area = math.pi * radius ** 2

# %%
# Date: 28.01.2024
# Step: 4.3.6
# Url: https://stepik.org/lesson/794582/step/6?unit=797335

class Bee:
    def __init__(self, x: int = 0, y: int = 0):
        self.x = x
        self.y = y
    
    def move_up(self, n: int):
        self.y += n
    
    def move_down(self, n):
        self.y -= n
    
    def move_left(self, n):
        self.x -= n
    
    def move_right(self, n):
        self.x += n

# %%
# Date: 28.01.2024
# Step: 4.3.7
# Url: https://stepik.org/lesson/794582/step/7?unit=797335

class Gun:
    def __init__(self):
        self.counter = 0

    def shoot(self):
        if self.counter % 2 == 0:
            print("pif")
        else:
            print("paf")
        self.counter += 1

# %%
# Date: 28.01.2024
# Step: 4.3.8
# Url: https://stepik.org/lesson/794582/step/8?unit=797335

class Gun:
    def __init__(self):
        self.counter = 0
    
    def shoot(self):
        if self.counter % 2 == 0:
            print("pif")
        else:
            print("paf")
        self.counter += 1
    
    def shots_count(self) -> int:
        return self.counter
    
    def shots_reset(self):
        self.counter = 0

# %%
# Date: 28.01.2024
# Step: 4.3.9
# Url: https://stepik.org/lesson/794582/step/9?unit=797335

class Scales:
    def __init__(self):
        self.right_scale = 0
        self.left_scale = 0

    def add_right(self, weight: int):
        self.right_scale += weight

    def add_left(self, weight: int):
        self.left_scale += weight

    def get_result(self):
        if self.left_scale == self.right_scale:
            return "Весы в равновесии"
        elif self.left_scale > self.right_scale:
            return "Левая чаша тяжелее"
        else:
            return "Правая чаша тяжелее"

# %%
# Date: 28.01.2024
# Step: 4.3.10
# Url: https://stepik.org/lesson/794582/step/10?unit=797335

class Vector:
    def __init__(self, x: int = 0, y: int = 0):
        self.x = x
        self.y = y
    
    def abs(self) -> float:
        return (self.x ** 2 + self.y ** 2) ** 0.5

# %%
# Date: 28.01.2024
# Step: 4.3.11
# Url: https://stepik.org/lesson/794582/step/11?unit=797335

class Numbers:
    def __init__(self):
        self.numbers = []
    
    def add_number(self, n: int):
        self.numbers.append(n)
    
    def get_even(self):
        return [i for i in self.numbers if i % 2 == 0]
    
    def get_odd(self):
        return [i for i in self.numbers if i % 2 != 0]

# %%
# Date: 28.01.2024
# Step: 4.3.12
# Url: https://stepik.org/lesson/794582/step/12?unit=797335

class TextHandler:
    def __init__(self):
        self.words = []
    
    def add_words(self, text: str):
        self.words.extend(text.split())
    
    def get_shortest_words(self):
        if len(self.words) != 0:
            min_word_len: int = len(min(self.words, key = len))
            return [i for i in self.words if len(i) == min_word_len]
        else:
            return self.words
    
    def get_longest_words(self):
        if len(self.words) != 0:
            max_word_len: int = len(max(self.words, key = len))
            return [i for i in self.words if len(i) == max_word_len]
        else:
            return self.words

# %%
# Date: 28.01.2024
# Step: 4.3.12
# Url: https://stepik.org/lesson/794582/step/12?unit=797335

class Todo:
    def __init__(self):
        self.things = []
    
    def add(self, task: str, priority: int) -> None:
        self.things.append((task, priority))
    
    def get_by_priority(self, n: int):
        if len(self.things) == 0:
            return self.things
        return [i[0] for i in self.things if i[1] == n]
    
    def get_low_priority(self):
        if len(self.things) == 0:
            return self.things
        priority: int = min(self.things, key = lambda x: x[1])[1]
        return self.get_by_priority(priority)
    
    def get_high_priority(self):
        if len(self.things) == 0:
            return self.things
        priority: int = max(self.things, key = lambda x: x[1])[1]
        return self.get_by_priority(priority)

# %%
# Date: 28.01.2024
# Step: 4.3.14
# Url: https://stepik.org/lesson/794582/step/14?unit=797335

class Postman:
    def __init__(self):
        self.delivery_data = []
    
    def add_delivery(self, street: str, house: int, flat: int) -> None:
        self.delivery_data.append((street, house, flat))
    
    def get_houses_for_street(self, street: str) -> list:
        houses: list = []
        for house in [i for i in self.delivery_data if i[0] == street]:
            if house[1] not in houses:
                houses.append(house[1])
        
        return houses
    
    def get_flats_for_house(self, street: str, house: int) -> list:
        flats: list = []
        for flat in [i for i in self.delivery_data if i[0] == street and i[1] == house]:
            if flat[2] not in flats:
                flats.append(flat[2])
        
        return flats

# %%
# Date: 
# Step: 4.3.15
# Url: https://stepik.org/lesson/794582/step/15?unit=797335

# %%
# Date: 
# Step: 4.3.16
# Url: https://stepik.org/lesson/794582/step/16?unit=797335

# %% [markdown]
# # 4.4 Модификаторы доступа и аксессоры

# %%
# Date: 31.01.2024
# Step: 4.4.15
# Url: https://stepik.org/lesson/793864/step/15?unit=796596

class Circle:
    def __init__(self, radius: float):
        self._radius = radius
        self._area = math.pi * radius ** 2
        self._diameter = radius * 2
    
    def get_radius(self) -> float:
        return self._radius
    
    def get_area(self) -> float:
        return self._area
    
    def get_diameter(self) -> float:
        return self._diameter

# %%
# Date: 31.01.2024
# Step: 4.4.16
# Url: https://stepik.org/lesson/793864/step/16?unit=796596

class BankAccount:
    def __init__(self, balance: int = 0):
        self._balance = balance
    
    def get_balance(self) -> int:
        return self._balance
    
    def deposit(self, amount: int) -> None:
        self._balance += amount
    
    def withdraw(self, amount: int) -> None:
        if amount > self._balance:
            raise ValueError("На счете недостаточно средств")
        
        self._balance -= amount
    
    def transfer(self, account, amount: int) -> None:
        self.withdraw(amount = amount)
        account.deposit(amount = amount)

# %%
# Date: 31.01.2024
# Step: 4.4.17
# Url: https://stepik.org/lesson/793864/step/17?unit=796596

class User:
    def __init__(self, name: str, age: int) -> None:
        if isinstance(name, str) and name.isalpha():
            self._name = name
        else:
            raise ValueError("Некорректное имя")

        if isinstance(age, int) and 0 <= age <= 110:
            self._age = age
        else:
            raise ValueError("Некорректный возраст")
    
    def get_name(self) -> str:
        return self._name
    
    def set_name(self, name: str) -> None:
        if isinstance(name, str) and name.isalpha():
            self._name = name
        else:
            raise ValueError("Некорректное имя")
    
    def get_age(self) -> int:
        return self._age
    
    def set_age(self, new_age: int) -> None:
        if isinstance(new_age, int) and 0 <= new_age <= 110:
            self._age = new_age
        else:
            raise ValueError("Некорректный возраст")

# %% [markdown]
# # 4.5 Свойства, функция property()

# %%
# Date: 31.01.2024
# Step: 4.5.13
# Url: https://stepik.org/lesson/796462/step/13?unit=799267

class Rectangle:
    def __init__(self, length: int, width: int) -> None:
        self.length = length
        self.width = width
    
    def get_perimeter(self):
        return self.length * 2 + self.width * 2
    
    def get_area(self):
        return self.length * self.width
    
    perimeter = property(get_perimeter)
    area = property(get_area)

# %%
# Date: 01.02.2024
# Step: 4.5.14
# Url: https://stepik.org/lesson/796462/step/14?unit=799267

class HourClock:
    def __init__(self, hours: int) -> None:
        if isinstance(hours, int) and 1 <= hours <= 12:
            self._hours = hours
        else:
            raise ValueError("Некорректное время")
    
    def get_hours(self) -> int:
        return self._hours
    
    def set_hours(self, new_hours: int) -> None:
        if isinstance(new_hours, int) and 1 <= new_hours <= 12:
            self._hours = new_hours
        else:
            raise ValueError("Некорректное время")
    
    hours = property(get_hours, set_hours)

# %%
# Date: 01.02.2024
# Step: 4.5.15
# Url: https://stepik.org/lesson/796462/step/15?unit=799267

class Person:
    def __init__(self, name: str, surname: str) -> None:
        self.name = name
        self.surname = surname
    
    def get_fullname(self) -> str:
        return f"{self.name} {self.surname}"
    
    def set_fullname(self, new_fullname: str) -> None:
        self.name, self.surname = new_fullname.split()
    
    fullname = property(get_fullname, set_fullname)

# %% [markdown]
# # 4.6 Декоратор @property

# %%
# Date: 01.02.2024
# Step: 4.6.13
# Url: https://stepik.org/lesson/801862/step/13?unit=804839

class Person:
    def __init__(self, name: str, surname: str) -> None:
        self.name = name
        self.surname = surname
    
    @property
    def fullname(self) -> str:
        return f"{self.name} {self.surname}"
    
    @fullname.setter
    def fullname(self, new_fullname) -> None:
        self.name, self.surname = new_fullname.split()

# %%
# Date: 01.02.2024
# Step: 4.6.14
# Url: https://stepik.org/lesson/801862/step/14?unit=804839

class Account:
    def __init__(self, login: str, password: str) -> None:
        self._login = login
        self._password = Account.hash_function(password = password)
    
    @staticmethod
    def hash_function(password: str):
        hash_value = 0
        for char, index in zip(password, range(len(str(password)))):
            hash_value += ord(char) * index
        return hash_value % 10**9
    
    @property
    def login(self) -> str:
        return self._login
    
    @login.setter
    def login(self, login: str) -> None:
        raise AttributeError("Изменение логина невозможно")
    
    @property
    def password(self) -> str:
        return self._password
    
    @password.setter
    def password(self, password: str) -> None:
        hash_password = Account.hash_function(password = password)
        self._password = hash_password

# %%
account = Account('timyr-guev', 'lovebeegeek')
account.login = 'timyrik30'

# %%
# Date: 01.02.2024
# Step: 4.6.15
# Url: https://stepik.org/lesson/801862/step/15?unit=804839

# %%
# Date: 01.02.2024
# Step: 4.6.16
# Url: https://stepik.org/lesson/801862/step/16?unit=804839

class Color:
    def __init__(self, hexcode: str) -> None:
        self.r = int(hexcode[:2], 16)
        self.g = int(hexcode[2:4], 16)
        self.b = int(hexcode[4:], 16)
    
    @property
    def hexcode(self) -> str:
        return "{:02X}{:02X}{:02X}".format(self.r, self.g, self.b)
    
    @hexcode.setter
    def hexcode(self, new_hexcode: str) -> None:
        self.r = int(new_hexcode[:2], 16)
        self.g = int(new_hexcode[2:4], 16)
        self.b = int(new_hexcode[4:], 16)

# %% [markdown]
# # 4.7 Декораторы @classmethod и @staticmethod

# %%
# Date: 
# Step: 
# Url:

# %% [markdown]
# # 4.8 Декоратор @singledispatchmethod

# %%
# Date: 
# Step: 
# Url:
