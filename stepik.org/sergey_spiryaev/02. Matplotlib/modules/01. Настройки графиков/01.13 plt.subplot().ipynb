# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
values: np.ndarray = np.linspace(start=0, stop=10, num=5)
y1: np.ndarray = values ** 2
y2: np.ndarray = values ** 3
y3: np.ndarray = values ** 0.5
y4: np.ndarray = np.sin(values ** 2)

# %%
plt.subplot(2, 2, 1)
plt.plot(
    values,
    y1,
    color="darkgreen",
    linewidth=1,
    marker="o",
    markerfacecolor="green",
    markersize=5,
    markeredgewidth=1,
    markeredgecolor="black",
)
plt.title(label="y1")

plt.subplot(2, 2, 2)
plt.plot(
    values,
    y2,
    color="darkred",
    linewidth=1,
    marker="o",
    markerfacecolor="red",
    markersize=5,
    markeredgewidth=1,
    markeredgecolor="black",
)
plt.title(label="y2")

plt.subplot(2, 2, 3)
plt.plot(
    values,
    y3,
    color="yellow",
    linewidth=1,
    marker="o",
    markerfacecolor="orange",
    markersize=5,
    markeredgewidth=1,
    markeredgecolor="black",
)
plt.title(label="y3")

plt.subplot(2, 2, 4)
plt.plot(
    values,
    y4,
    color="blue",
    linewidth=1,
    marker="o",
    markerfacecolor="royalblue",
    markersize=5,
    markeredgewidth=1,
    markeredgecolor="black",
)
plt.title(label="y4")

plt.suptitle('Графики y1-4')
plt.tight_layout()

plt.show()

# %%
plt.figure(figsize=(12, 7))

plt.subplot(4, 4, 1)
plt.plot(
    values,
    y1,
    color="red",
    linewidth=1,
    marker="o",
    markerfacecolor="red",
    markersize=5,
    markeredgewidth=1,
    markeredgecolor="black",
)

plt.subplot(4, 4, 2)
plt.plot(
    values,
    y2,
    color="blue",
    linewidth=1,
    marker="o",
    markerfacecolor="blue",
    markersize=5,
    markeredgewidth=1,
    markeredgecolor="black",
)

plt.subplot(4, 4, 3)
plt.plot(
    values,
    y3,
    color="green",
    linewidth=1,
    marker="o",
    markerfacecolor="green",
    markersize=5,
    markeredgewidth=1,
    markeredgecolor="black",
)

plt.subplot(4, 4, 4)
plt.plot(
    values,
    y4,
    color="yellow",
    linewidth=1,
    marker="o",
    markerfacecolor="yellow",
    markersize=5,
    markeredgewidth=1,
    markeredgecolor="black",
)

plt.subplot(4, 3, 4)
plt.plot(
    values,
    y1,
    color="magenta",
    linewidth=1,
    marker="o",
    markerfacecolor="magenta",
    markersize=5,
    markeredgewidth=1,
    markeredgecolor="black",
)

plt.subplot(4, 3, 5)
plt.plot(
    values,
    y2,
    color="cyan",
    linewidth=1,
    marker="o",
    markerfacecolor="cyan",
    markersize=5,
    markeredgewidth=1,
    markeredgecolor="black",
)

plt.subplot(4, 3, 6)
plt.plot(
    values,
    y3,
    color="orange",
    linewidth=1,
    marker="o",
    markerfacecolor="orange",
    markersize=5,
    markeredgewidth=1,
    markeredgecolor="black",
)

plt.subplot(4, 2, 5)
plt.plot(
    values,
    y4,
    color="gray",
    linewidth=1,
    marker="o",
    markerfacecolor="gray",
    markersize=5,
    markeredgewidth=1,
    markeredgecolor="black",
)

plt.subplot(4, 2, 6)
plt.plot(
    values,
    y1,
    color="brown",
    linewidth=1,
    marker="o",
    markerfacecolor="brown",
    markersize=5,
    markeredgewidth=1,
    markeredgecolor="black",
)

plt.subplot(4, 1, 4)
plt.plot(
    values,
    y2,
    color="red",
    linewidth=1,
    marker="o",
    markerfacecolor="red",
    markersize=5,
    markeredgewidth=1,
    markeredgecolor="black",
)

plt.tight_layout()

plt.show()
# Out:
# C:\Users\d.zakharchenko\AppData\Local\Temp\ipykernel_4028\4179734984.py:133: UserWarning: tight_layout not applied: number of columns in subplot specifications must be multiples of one another.
#   plt.tight_layout()
