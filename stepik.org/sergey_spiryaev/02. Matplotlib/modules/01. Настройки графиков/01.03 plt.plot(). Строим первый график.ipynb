# %% [markdown]
# # Step 1 - Lection

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.plot([1, 2, 3, 4, 5]);

# %%
values: dict[str, list[int]] = {
    "x": [2, 4, 8, 12, 15, 20, 25],
    "y": [0, 5, 4, 11, 12, 10, 9]
}

dataframe = pd.DataFrame(
    data=values
)

display(dataframe)
# Out:
#     x   y
# 0   2   0
# 1   4   5
# 2   8   4
# 3  12  11
# 4  15  12
# 5  20  10
# 6  25   9

# %%
plt.plot(
    dataframe["x"],
    dataframe["y"]
);
