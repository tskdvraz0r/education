# %% [markdown]
# # Step 1 - Lesson

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
values: dict[str, list[int]] = {
    "x": [2, 4, 8, 12, 15, 20, 25],
    "y": [0, 5, 4, 11, 12, 10, 9]
}

dataframe = pd.DataFrame(data=values)

display(dataframe)
# Out:
#     x   y
# 0   2   0
# 1   4   5
# 2   8   4
# 3  12  11
# 4  15  12
# 5  20  10
# 6  25   9

# %%
plt.figure()
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.show()

# %%
plt.figure(figsize=(8, 6), dpi=200)
plt.show()

# %% [markdown]
# # Step 2 - Lesson

# %%
fig = plt.figure(figsize=(7, 5), facecolor="olive")
ax = plt.axes([0, 0, 1, 1])
plt.show()

# %%
fig = plt.figure(figsize=(7, 5), facecolor="olive")
ax1 = plt.axes([0, 0, 0.5, 0.5])
ax2 = plt.axes([0.5, 0.5, 0.5, 0.5])
plt.show()

# %%
fig = plt.figure(figsize=(7, 5), facecolor="olive")
ax1 = plt.axes([0, 0, 0.5, 0.5])
ax2 = plt.axes([0.5, 0.5, 0.75, 0.75])
plt.show()

# %%
fig = plt.figure(figsize=(7, 5), facecolor="olive")
ax = fig.add_axes([0, 0, 1, 1])
plt.show()
