# %%
import sys

sys.path.insert(0, "/Users/dmitrijkolganov/Yandex.Disk.localized/git/pet_projects/docker")
from docker import Docker

# %% [markdown]
# # Step 3

# %%
Docker.Image.ls()
# Out:
# REPOSITORY   TAG       IMAGE ID   CREATED   SIZE

# %%
Docker.Container.ls()
# Out:
# CONTAINER ID   IMAGE     COMMAND   CREATED   STATUS    PORTS     NAMES

# %%
Docker.Container.ls(options="-a")
# Out:
# CONTAINER ID   IMAGE     COMMAND   CREATED   STATUS    PORTS     NAMES

# %%
Docker.Image.pull(name="node")
Docker.Image.pull(name="node:16")
Docker.Image.pull(name="node:alpine")
Docker.Image.pull(name="yandex/clickhouse-server")
# Out:
# Using default tag: latest
# latest: Pulling from library/node
# 6ee0baa58a3d: Pulling fs layer
# 992a857ef575: Pulling fs layer
# 3861a6536e4e: Pulling fs layer
# e5e6faea05ea: Pulling fs layer
# ab8d26971fbf: Pulling fs layer
# 92111119a688: Pulling fs layer
# f28e70d14cf1: Pulling fs layer
# b82cdbb2c29e: Pulling fs layer
# e5e6faea05ea: Waiting
# ab8d26971fbf: Waiting
# 92111119a688: Waiting
# f28e70d14cf1: Waiting
# b82cdbb2c29e: Waiting
# 6ee0baa58a3d: Download complete
# 3861a6536e4e: Verifying Checksum
# 3861a6536e4e: Download complete
# 992a857ef575: Download complete
# ab8d26971fbf: Verifying Checksum
# ab8d26971fbf: Download complete
# f28e70d14cf1: Download complete
# b82cdbb2c29e: Verifying Checksum
# b82cdbb2c29e: Download complete
# 6ee0baa58a3d: Pull complete
# 92111119a688: Verifying Checksum
# 92111119a688: Download complete
# 992a857ef575: Pull complete
# e5e6faea05ea: Verifying Checksum
# e5e6faea05ea: Download complete
# 3861a6536e4e: Pull complete
# ...

# %%
Docker.Image.ls()
# Out:
# REPOSITORY                 TAG       IMAGE ID       CREATED        SIZE
# node                       alpine    7544d076ab45   3 days ago     139MB
# node                       latest    0ef75c94f02b   7 days ago     1.1GB
# node                       16        ba2a23dcc030   6 months ago   856MB
# yandex/clickhouse-server   latest    c739327b5607   2 years ago    826MB

# %%
Docker.Image.rm(image="node:alpine")
Docker.Image.rm(image="ba2a23dcc030")
# Out:
# Untagged: node:alpine
# Untagged: node@sha256:577f8eb599858005100d84ef3fb6bd6582c1b6b17877a393cdae4bfc9935f068
# Deleted: sha256:7544d076ab45456a908d66876f5d4ca406cc77ed2177ee153486c5ff06fbd212
# Deleted: sha256:030c7e38f6be08ed328c4a49bc172b33d894ff51689e66cad91334675a82816a
# Deleted: sha256:2cbe6d56dd3fca8585226fb7d2c766c005ec91b81f936fe8a5d06f20ac94b9bb
# Deleted: sha256:5200610c0bffad4490092ad51a92939aa66ba860067de624c7ae7298aed6e891
# Deleted: sha256:b09314aec293bcd9a8ee5e643539437b3846f9e5e55f79e282e5f67e3026de5e
# Untagged: node:16
# Untagged: node@sha256:f77a1aef2da8d83e45ec990f45df50f1a286c5fe8bbfb8c6e4246c6389705c0b
# Deleted: sha256:ba2a23dcc03063459949138c2ce528c71ab78d4e5a58af11162e7eed7f4a7e3c
# Deleted: sha256:91d336b34135f936d41565701ec2f6000e8e5d517225679810c2859be2410ca0
# Deleted: sha256:30bad493b2aebc436baf592766d0bbc9a878f350fb2332a57d78190918aea0cb
# Deleted: sha256:e27077bb97f4c251a32d27321bbb8218806d3b428ffd6b45fbf1d95ec3817fa3
# ...

# %%
Docker.Image.ls()
# Out:
# REPOSITORY                 TAG       IMAGE ID       CREATED       SIZE
# node                       latest    0ef75c94f02b   7 days ago    1.1GB
# yandex/clickhouse-server   latest    c739327b5607   2 years ago   826MB

# %% [markdown]
# # Step 4

# %%
Docker.Container.ls(options="-a")
# Out:
# CONTAINER ID   IMAGE     COMMAND   CREATED   STATUS    PORTS     NAMES

# %%
Docker.Container.run(image="node:latest")
# Out:
# Unable to find image 'node:latest' locally
# latest: Pulling from library/node
# 71215d55680c: Pulling fs layer
# 3cb8f9c23302: Pulling fs layer
# 5f899db30843: Pulling fs layer
# 567db630df8d: Pulling fs layer
# f4ac4e9f5ffb: Pulling fs layer
# 375735fcaa7a: Pulling fs layer
# c12db77023cd: Pulling fs layer
# ac50344c1606: Pulling fs layer
# 567db630df8d: Waiting
# f4ac4e9f5ffb: Waiting
# 375735fcaa7a: Waiting
# c12db77023cd: Waiting
# ac50344c1606: Waiting
# 3cb8f9c23302: Verifying Checksum
# 3cb8f9c23302: Download complete
# 5f899db30843: Verifying Checksum
# 5f899db30843: Download complete
# 71215d55680c: Verifying Checksum
# 71215d55680c: Download complete
# f4ac4e9f5ffb: Verifying Checksum
# f4ac4e9f5ffb: Download complete
# c12db77023cd: Download complete
# ac50344c1606: Verifying Checksum
# ac50344c1606: Download complete
# 71215d55680c: Pull complete
# 375735fcaa7a: Verifying Checksum
# 375735fcaa7a: Download complete
# 3cb8f9c23302: Pull complete
# ...

# %%
Docker.Container.ls(options="-a")
# Out:
# CONTAINER ID   IMAGE         COMMAND                  CREATED         STATUS                     PORTS     NAMES
# 1950715f15eb   node:latest   "docker-entrypoint.s…"   4 seconds ago   Exited (0) 2 seconds ago             vigilant_galileo

# %%
Docker.Container.run(image="yandex/clickhouse-server", options="-d")
# Out:
# a4c21085aed4e86a1efafb358d9d8486ee8c15209db81b54dee94f743f88b5a7

# %%
Docker.Container.ls(options="-a")
# Out:
# CONTAINER ID   IMAGE                      COMMAND                  CREATED          STATUS                      PORTS                          NAMES
# a4c21085aed4   yandex/clickhouse-server   "/entrypoint.sh"         7 seconds ago    Up 6 seconds                8123/tcp, 9000/tcp, 9009/tcp   condescending_dubinsky
# 1950715f15eb   node:latest                "docker-entrypoint.s…"   14 seconds ago   Exited (0) 12 seconds ago                                  vigilant_galileo

# %%
Docker.Container.stop(container="condescending_dubinsky")
# Out:
# condescending_dubinsky

# %%
Docker.Container.ls(options="-a")
# Out:
# CONTAINER ID   IMAGE                      COMMAND                  CREATED          STATUS                      PORTS     NAMES
# a4c21085aed4   yandex/clickhouse-server   "/entrypoint.sh"         21 seconds ago   Exited (0) 1 second ago               condescending_dubinsky
# 1950715f15eb   node:latest                "docker-entrypoint.s…"   28 seconds ago   Exited (0) 26 seconds ago             vigilant_galileo

# %%
Docker.Container.start(container="condescending_dubinsky")
# Out:
# condescending_dubinsky

# %%
Docker.Container.ls(options="-a")
# Out:
# CONTAINER ID   IMAGE                      COMMAND                  CREATED          STATUS                      PORTS                          NAMES
# a4c21085aed4   yandex/clickhouse-server   "/entrypoint.sh"         27 seconds ago   Up 1 second                 8123/tcp, 9000/tcp, 9009/tcp   condescending_dubinsky
# 1950715f15eb   node:latest                "docker-entrypoint.s…"   34 seconds ago   Exited (0) 32 seconds ago                                  vigilant_galileo

# %%
Docker.Container.stop(container="condescending_dubinsky")
# Out:
# condescending_dubinsky

# %% [markdown]
# # Step 5

# %%
Docker.Container.run(image="yandex/clickhouse-server", options="-d --name test_name")
# Out:
# 4da74b3d4d9c3ff572f1e184dc88e6828549fbe476f35254ea406efcf4018b34

# %%
Docker.Container.ls(options="-a")
# Out:
# CONTAINER ID   IMAGE                      COMMAND                  CREATED          STATUS                      PORTS                          NAMES
# 4da74b3d4d9c   yandex/clickhouse-server   "/entrypoint.sh"         3 seconds ago    Up 2 seconds                8123/tcp, 9000/tcp, 9009/tcp   test_name
# a4c21085aed4   yandex/clickhouse-server   "/entrypoint.sh"         42 seconds ago   Exited (0) 7 seconds ago                                   condescending_dubinsky
# 1950715f15eb   node:latest                "docker-entrypoint.s…"   49 seconds ago   Exited (0) 47 seconds ago                                  vigilant_galileo

# %%
Docker.Container.ls(options="-q")
# Out:
# 4da74b3d4d9c

# %%
Docker.Container.stop(container="$(docker container ls -q)")
# Out:
# 4da74b3d4d9c

# %%
Docker.Container.ls(options="-a")
# Out:
# CONTAINER ID   IMAGE                      COMMAND                  CREATED              STATUS                          PORTS     NAMES
# 4da74b3d4d9c   yandex/clickhouse-server   "/entrypoint.sh"         19 seconds ago       Exited (0) 3 seconds ago                  test_name
# a4c21085aed4   yandex/clickhouse-server   "/entrypoint.sh"         58 seconds ago       Exited (0) 23 seconds ago                 condescending_dubinsky
# 1950715f15eb   node:latest                "docker-entrypoint.s…"   About a minute ago   Exited (0) About a minute ago             vigilant_galileo

# %%
Docker.Container.rm(container="$(docker container ls -qa)")
# Out:
# 4da74b3d4d9c
# a4c21085aed4
# 1950715f15eb

# %%
Docker.Container.run(image="yandex/clickhouse-server", options="-d")
# Out:
# 4f66093b64cb9af5536631e96e5a88c75a1ea11fd0828172eb053d8765059c4e

# %%
Docker.Container.ls()
# Out:
# CONTAINER ID   IMAGE                      COMMAND            CREATED         STATUS         PORTS                          NAMES
# 4f66093b64cb   yandex/clickhouse-server   "/entrypoint.sh"   4 seconds ago   Up 3 seconds   8123/tcp, 9000/tcp, 9009/tcp   distracted_matsumoto

# %% [raw]
# docker exec -it <container name> bash
# mkdir test
# touch test/test_file.txt
# echo 13 > test/test_file.txt
# cat test/test_file.txt

# %%
Docker.Container.commit(container="distracted_matsumoto", repository="test_clickhouse:1")
# Out:
# sha256:20883462fb6f79cb715d7d511a809486837f896445982392eb504126f56a1d2e

# %%
Docker.Image.ls()
# Out:
# REPOSITORY                 TAG       IMAGE ID       CREATED         SIZE
# test_clickhouse            1         20883462fb6f   3 seconds ago   826MB
# node                       latest    c3978d05bc68   7 days ago      1.1GB
# node                       <none>    0ef75c94f02b   7 days ago      1.1GB
# yandex/clickhouse-server   latest    c739327b5607   2 years ago     826MB

# %%
Docker.Container.stop(container="$(docker container ls -q)")
# Out:
# 4f66093b64cb

# %%
Docker.Container.rm(container="$(docker container ls -qa)")
# Out:
# 4f66093b64cb

# %%
Docker.Image.rm(image="$(docker image ls)")
# Out:
# Untagged: test_clickhouse:1
# Deleted: sha256:20883462fb6f79cb715d7d511a809486837f896445982392eb504126f56a1d2e
# Deleted: sha256:6ece3d764c2bdee994f230d5e390de72fb46ce1402420d6e3aae7538c7b57cdb
# Untagged: node:latest
# Deleted: sha256:c3978d05bc68452fec21b7e4e76399380f4e7505d7f9f034c5981678732f6e96
# Deleted: sha256:dc94ebc9ec1a98bd29c3c84014ed4bf85bf944d9298aa5c7328a98f257836427
# Deleted: sha256:32dbf0d3fd980ffba8dd592281cc1f4daef909c84f5d55aeb83a37eaf69d92d5
# Deleted: sha256:74852d5ffe9c9fed9ddfb30ddb2a2914769b42987e1543c04c309127e499f6cf
# Deleted: sha256:529e9f64ea6c0660f0ee3dd29c98367d85ed90563d7767137113565703dceadc
# Deleted: sha256:83aa18cbe4a99007ea67f47ce6bec0756273775dac527ebaf8a0c224193f2b95
# Deleted: sha256:9a05df6eae3b21d822cd02d428c88c05ab67d5e8d11014884742ab22b7a44a7a
# Deleted: sha256:312ee2ba731589de51a59f88b05a206c45b3f07d7ac7c87eca16c0fef7475d74
# Deleted: sha256:0238a17903242951b944d01ab189a30ac237c715121f14565a2af8b078415d97
# ...

# %%
Docker.Container.ls(options="-a")
# Out:
# CONTAINER ID   IMAGE     COMMAND   CREATED   STATUS    PORTS     NAMES

# %%
Docker.Image.ls()
# Out:
# REPOSITORY   TAG       IMAGE ID   CREATED   SIZE
