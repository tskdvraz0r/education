# %%
import sys

sys.path.insert(0, "/Users/dmitrijkolganov/Yandex.Disk.localized/git/pet_projects/docker")
from docker import Docker

# %% [markdown]
# # Step 3

# %%
Docker.images()
# Out:
# REPOSITORY                 TAG       IMAGE ID       CREATED       SIZE
# node                       latest    c3978d05bc68   5 days ago    1.1GB
# node                       <none>    0ef75c94f02b   5 days ago    1.1GB
# yandex/clickhouse-server   latest    c739327b5607   2 years ago   826MB

# %%
Docker.ps()
# Out:
# CONTAINER ID   IMAGE     COMMAND   CREATED   STATUS    PORTS     NAMES

# %%
Docker.ps(options="-a")
# Out:
# CONTAINER ID   IMAGE     COMMAND   CREATED   STATUS    PORTS     NAMES

# %%
Docker.pull(image="node")
Docker.pull(image="node:16")
Docker.pull(image="node:alpine")
Docker.pull(image="yandex/clickhouse-server")
# Out:
# Using default tag: latest
# latest: Pulling from library/node
# 6ee0baa58a3d: Pulling fs layer
# 992a857ef575: Pulling fs layer
# 3861a6536e4e: Pulling fs layer
# e5e6faea05ea: Pulling fs layer
# ab8d26971fbf: Pulling fs layer
# 92111119a688: Pulling fs layer
# f28e70d14cf1: Pulling fs layer
# b82cdbb2c29e: Pulling fs layer
# ab8d26971fbf: Waiting
# 92111119a688: Waiting
# f28e70d14cf1: Waiting
# b82cdbb2c29e: Waiting
# e5e6faea05ea: Waiting
# 992a857ef575: Verifying Checksum
# 992a857ef575: Download complete
# 6ee0baa58a3d: Verifying Checksum
# 6ee0baa58a3d: Download complete
# ab8d26971fbf: Verifying Checksum
# ab8d26971fbf: Download complete
# 6ee0baa58a3d: Pull complete
# 992a857ef575: Pull complete
# 3861a6536e4e: Verifying Checksum
# 3861a6536e4e: Download complete
# f28e70d14cf1: Download complete
# 3861a6536e4e: Pull complete
# b82cdbb2c29e: Verifying Checksum
# b82cdbb2c29e: Download complete
# 92111119a688: Verifying Checksum
# 92111119a688: Download complete
# ...

# %%
Docker.images()
# Out:
# REPOSITORY                 TAG       IMAGE ID       CREATED        SIZE
# node                       alpine    7544d076ab45   37 hours ago   139MB
# node                       latest    0ef75c94f02b   5 days ago     1.1GB
# node                       16        ba2a23dcc030   6 months ago   856MB
# yandex/clickhouse-server   latest    c739327b5607   2 years ago    826MB

# %%
Docker.rmi(image_or_id="node:alpine")
Docker.rmi(image_or_id="ba2a23dcc030")
# Out:
# Untagged: node:alpine
# Untagged: node@sha256:577f8eb599858005100d84ef3fb6bd6582c1b6b17877a393cdae4bfc9935f068
# Deleted: sha256:7544d076ab45456a908d66876f5d4ca406cc77ed2177ee153486c5ff06fbd212
# Deleted: sha256:030c7e38f6be08ed328c4a49bc172b33d894ff51689e66cad91334675a82816a
# Deleted: sha256:2cbe6d56dd3fca8585226fb7d2c766c005ec91b81f936fe8a5d06f20ac94b9bb
# Deleted: sha256:5200610c0bffad4490092ad51a92939aa66ba860067de624c7ae7298aed6e891
# Deleted: sha256:b09314aec293bcd9a8ee5e643539437b3846f9e5e55f79e282e5f67e3026de5e
# Untagged: node:16
# Untagged: node@sha256:f77a1aef2da8d83e45ec990f45df50f1a286c5fe8bbfb8c6e4246c6389705c0b
# Deleted: sha256:ba2a23dcc03063459949138c2ce528c71ab78d4e5a58af11162e7eed7f4a7e3c
# Deleted: sha256:91d336b34135f936d41565701ec2f6000e8e5d517225679810c2859be2410ca0
# Deleted: sha256:30bad493b2aebc436baf592766d0bbc9a878f350fb2332a57d78190918aea0cb
# Deleted: sha256:e27077bb97f4c251a32d27321bbb8218806d3b428ffd6b45fbf1d95ec3817fa3
# ...

# %%
Docker.images()
# Out:
# REPOSITORY                 TAG       IMAGE ID       CREATED       SIZE
# node                       latest    0ef75c94f02b   5 days ago    1.1GB
# yandex/clickhouse-server   latest    c739327b5607   2 years ago   826MB

# %% [markdown]
# # Step 4

# %%
Docker.ps(options="-a")
# Out:
# CONTAINER ID   IMAGE     COMMAND   CREATED   STATUS    PORTS     NAMES

# %%
Docker.run(image="node:latest")
# Out:
# Unable to find image 'node:latest' locally
# latest: Pulling from library/node
# 71215d55680c: Pulling fs layer
# 3cb8f9c23302: Pulling fs layer
# 5f899db30843: Pulling fs layer
# 567db630df8d: Pulling fs layer
# f4ac4e9f5ffb: Pulling fs layer
# 375735fcaa7a: Pulling fs layer
# c12db77023cd: Pulling fs layer
# ac50344c1606: Pulling fs layer
# f4ac4e9f5ffb: Waiting
# 375735fcaa7a: Waiting
# c12db77023cd: Waiting
# ac50344c1606: Waiting
# 567db630df8d: Waiting
# 3cb8f9c23302: Verifying Checksum
# 3cb8f9c23302: Download complete
# 71215d55680c: Verifying Checksum
# 71215d55680c: Download complete
# 5f899db30843: Verifying Checksum
# 5f899db30843: Download complete
# f4ac4e9f5ffb: Verifying Checksum
# f4ac4e9f5ffb: Download complete
# 71215d55680c: Pull complete
# 3cb8f9c23302: Pull complete
# c12db77023cd: Verifying Checksum
# c12db77023cd: Download complete
# ac50344c1606: Download complete
# 375735fcaa7a: Verifying Checksum
# 375735fcaa7a: Download complete
# ...

# %%
Docker.ps(options="-a")
# Out:
# CONTAINER ID   IMAGE         COMMAND                  CREATED              STATUS                          PORTS     NAMES
# 31f4098cf1ea   node:latest   "docker-entrypoint.s…"   About a minute ago   Exited (0) About a minute ago             elastic_khorana

# %%
Docker.run(image="yandex/clickhouse-server", options="-d")
# Out:
# f32551c1e69c200778658669779e1ef438a3b5cda12230f7ce87f1eaff139341

# %%
Docker.ps(options="-a")
# Out:
# CONTAINER ID   IMAGE                      COMMAND                  CREATED              STATUS                          PORTS                          NAMES
# f32551c1e69c   yandex/clickhouse-server   "/entrypoint.sh"         7 seconds ago        Up 7 seconds                    8123/tcp, 9000/tcp, 9009/tcp   affectionate_agnesi
# 31f4098cf1ea   node:latest                "docker-entrypoint.s…"   About a minute ago   Exited (0) About a minute ago                                  elastic_khorana

# %%
Docker.stop(name="affectionate_agnesi")
# Out:
# affectionate_agnesi

# %%
Docker.ps(options="-a")
# Out:
# CONTAINER ID   IMAGE                      COMMAND                  CREATED              STATUS                          PORTS     NAMES
# f32551c1e69c   yandex/clickhouse-server   "/entrypoint.sh"         35 seconds ago       Exited (0) 2 seconds ago                  affectionate_agnesi
# 31f4098cf1ea   node:latest                "docker-entrypoint.s…"   About a minute ago   Exited (0) About a minute ago             elastic_khorana

# %%
Docker.start(name="affectionate_agnesi")
# Out:
# affectionate_agnesi

# %%
Docker.ps(options="-a")
# Out:
# CONTAINER ID   IMAGE                      COMMAND                  CREATED              STATUS                          PORTS                          NAMES
# f32551c1e69c   yandex/clickhouse-server   "/entrypoint.sh"         48 seconds ago       Up 1 second                     8123/tcp, 9000/tcp, 9009/tcp   affectionate_agnesi
# 31f4098cf1ea   node:latest                "docker-entrypoint.s…"   About a minute ago   Exited (0) About a minute ago                                  elastic_khorana

# %%
Docker.stop(name="affectionate_agnesi")
# Out:
# affectionate_agnesi

# %% [markdown]
# # Step 5

# %%
Docker.run(image="yandex/clickhouse-server", options="-d --name test_name")
# Out:
# 673c98dcb103aead2a6a7ef49c856f272fe67a00cea0eb7c17f4487779a897c7

# %%
Docker.ps(options="-a")
# Out:
# CONTAINER ID   IMAGE                      COMMAND                  CREATED              STATUS                      PORTS                          NAMES
# 673c98dcb103   yandex/clickhouse-server   "/entrypoint.sh"         4 seconds ago        Up 3 seconds                8123/tcp, 9000/tcp, 9009/tcp   test_name
# f32551c1e69c   yandex/clickhouse-server   "/entrypoint.sh"         About a minute ago   Exited (0) 11 seconds ago                                  affectionate_agnesi
# 31f4098cf1ea   node:latest                "docker-entrypoint.s…"   2 minutes ago        Exited (0) 2 minutes ago                                   elastic_khorana

# %%
Docker.ps(options="-q")
# Out:
# 673c98dcb103

# %%
Docker.stop(name="$(docker ps -q)")
# Out:
# 673c98dcb103

# %%
Docker.ps(options="-a")
# Out:
# CONTAINER ID   IMAGE                      COMMAND                  CREATED          STATUS                      PORTS     NAMES
# 673c98dcb103   yandex/clickhouse-server   "/entrypoint.sh"         9 minutes ago    Exited (0) 16 seconds ago             test_name
# f32551c1e69c   yandex/clickhouse-server   "/entrypoint.sh"         10 minutes ago   Exited (0) 9 minutes ago              affectionate_agnesi
# 31f4098cf1ea   node:latest                "docker-entrypoint.s…"   11 minutes ago   Exited (0) 11 minutes ago             elastic_khorana

# %%
Docker.rm(name_or_id="$(docker ps -qa)")
# Out:
# 673c98dcb103
# f32551c1e69c
# 31f4098cf1ea

# %%
Docker.ps(options="-a")
# Out:
# CONTAINER ID   IMAGE     COMMAND   CREATED   STATUS    PORTS     NAMES

# %%
Docker.run(image="yandex/clickhouse-server", options="-d")
# Out:
# 77184142ae0ff5a619ef7563eec4964670d543db690c684b9c9deab3b41a0966

# %% [raw]
# docker exec -it elegant_austin bash
# mkdir test
# touch test/test_file.txt
# echo > 13 test/test_file.txt
# cat test/test_file.txt

# %%
Docker.commit(name="elegant_austin", new_name="test_clickhouse:0.1")
# Out:
# sha256:0536123dc5dbb29351c9f3b66fe59d25224cc63c38c2b235da969c231b4d1396

# %%
Docker.images()
# Out:
# REPOSITORY                 TAG       IMAGE ID       CREATED          SIZE
# test_clickhouse            0.1       0536123dc5db   19 seconds ago   827MB
# node                       latest    c3978d05bc68   5 days ago       1.1GB
# node                       <none>    0ef75c94f02b   5 days ago       1.1GB
# yandex/clickhouse-server   latest    c739327b5607   2 years ago      826MB

# %%
Docker.stop(name="$(docker ps -q)")
# Out:
# 77184142ae0f

# %%
Docker.ps(options="-a")
# Out:
# CONTAINER ID   IMAGE                      COMMAND            CREATED          STATUS                          PORTS     NAMES
# 77184142ae0f   yandex/clickhouse-server   "/entrypoint.sh"   10 minutes ago   Exited (0) About a minute ago             elegant_austin

# %%
Docker.rm(name_or_id="$(docker ps -qa)")
# Out:
# 77184142ae0f

# %%
Docker.ps(options="-a")
# Out:
# CONTAINER ID   IMAGE     COMMAND   CREATED   STATUS    PORTS     NAMES
