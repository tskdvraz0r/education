# %%
import sys

sys.path.insert(0, "/Users/dmitrijkolganov/Yandex.Disk.localized/git/pet_projects/docker")
from docker import Docker

# %% [markdown]
# # Step 3

# %%
Docker.Builder.build(
    options="-t custom_ubuntu:1",
    path_or_url="."
)
# Out:
# #0 building with "desktop-linux" instance using docker driver
#
# #1 [internal] load build definition from dockerfile
# #1 transferring dockerfile: 164B done
# #1 DONE 0.0s
#
# #2 [internal] load metadata for docker.io/library/ubuntu:20.04
# #2 DONE 0.6s
#
# #3 [internal] load .dockerignore
# #3 transferring context: 2B done
# #3 DONE 0.0s
#
# #4 [1/4] FROM docker.io/library/ubuntu:20.04@sha256:80ef4a44043dec4490506e6cc4289eeda2d106a70148b74b5ae91ee670e9c35d
# #4 DONE 0.0s
#
# #5 [internal] load build context
# #5 transferring context: 30B done
# #5 DONE 0.0s
#
# #6 [2/4] WORKDIR /home/user
# #6 CACHED
#
# #7 [3/4] COPY ./script.sh ./script.sh
# #7 CACHED
#
# #8 [4/4] RUN apt-get update && apt-get install -y vim wget curl git
# #8 0.264 Get:1 http://ports.ubuntu.com/ubuntu-ports focal InRelease [265 kB]
# #8 0.559 Get:2 http://ports.ubuntu.com/ubuntu-ports focal-updates InRelease [114 kB]
# #8 0.623 Get:3 http://ports.ubuntu.com/ubuntu-ports focal-backports InRelease [108 kB]
# ...

# %%
Docker.Image.ls()
# Out:
# REPOSITORY      TAG       IMAGE ID       CREATED        SIZE
# custom_ubuntu   1         f7768296dc19   1 second ago   262MB

# %%
Docker.System.df()
# Out:
# TYPE            TOTAL     ACTIVE    SIZE      RECLAIMABLE
# Images          1         0         262.3MB   262.3MB (100%)
# Containers      0         0         0B        0B
# Local Volumes   27        0         26.33MB   26.33MB (100%)
# Build Cache     7         0         180B      180B
