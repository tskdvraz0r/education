# %%
import sys

sys.path.insert(0, "/Users/dmitrijkolganov/Yandex.Disk.localized/git/pet_projects/docker")
from docker import Docker

# %% [markdown]
# # Step 9

# %%
image: str = "kcoursedocker/task-1.1"

# %%
Docker.Image.pull(name=image)
# Out:
# Using default tag: latest
# latest: Pulling from kcoursedocker/task-1.1
# e0b25ef51634: Pulling fs layer
# 481e54df602c: Pulling fs layer
# 481e54df602c: Verifying Checksum
# 481e54df602c: Download complete
# e0b25ef51634: Verifying Checksum
# e0b25ef51634: Download complete
# e0b25ef51634: Pull complete
# 481e54df602c: Pull complete
# Digest: sha256:d3b85600f4d6e7736038fe3b1f1c2158821abe79896c0f596fb78d5c8bfbfe18
# Status: Downloaded newer image for kcoursedocker/task-1.1:latest
# docker.io/kcoursedocker/task-1.1:latest

# %%
Docker.Container.run(image=image, options="--rm")
# Out:
# Welcome to the club

# %%
Docker.Container.ls()
# Out:
# CONTAINER ID   IMAGE     COMMAND   CREATED   STATUS    PORTS     NAMES

# %%
Docker.Container.ls(options="-a")
# Out:
# CONTAINER ID   IMAGE     COMMAND   CREATED   STATUS    PORTS     NAMES

# %%
Docker.Image.rm(image=image)
# Out:
# Untagged: kcoursedocker/task-1.1:latest
# Untagged: kcoursedocker/task-1.1@sha256:d3b85600f4d6e7736038fe3b1f1c2158821abe79896c0f596fb78d5c8bfbfe18
# Deleted: sha256:a7c163a4b2cdad1fe131d8667a207d2aee8f3f9ea7b48c7804b138310552c7e4
# Deleted: sha256:13c360f3487fbe0e3e4f1538e70ee8cd84bbb18bc6b83b802ff37336a1e5b311
# Deleted: sha256:c5ec52c98b3193052e15d783aca2bef10d8d829fa0d58fedfede511920b8f997

# %%
Docker.Image.ls()
# Out:
# REPOSITORY   TAG       IMAGE ID   CREATED   SIZE
