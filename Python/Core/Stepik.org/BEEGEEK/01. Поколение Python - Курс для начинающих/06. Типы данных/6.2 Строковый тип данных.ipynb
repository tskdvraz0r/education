# %% [markdown]
# # step_05
# Напишите программу, которая выводит текст: <br>
# *"Python is a great language!", said Fred. "I don't ever remember having this much fun before."*.
#
# **Примечание №1:** <br>
# Используйте конкатенацию строк.
#
# ## sample_input:
#
# ## sample_output:
# "Python is a great language!", said Fred. "I don't ever remember having this much fun before."

# %%
# date: 18.09.2021

print('''"Python is a great language!", said Fred. "I don't ever remember having this much fun before."''')
# Out:
# "Python is a great language!", said Fred. "I don't ever remember having this much fun before."

# %% [markdown]
# -----

# %% [markdown]
# # step_06 - What's Your Name?
# Напишите программу, которая считывает с клавиатуры две строки – имя и фамилию пользователя и выводит фразу: <br>
# *«Hello [введенное имя] [введенная фамилия]! You just delved into Python»*.
#
# **Формат входных данных:** <br>
# На вход программе подаётся две строки (имя и фамилия), каждая на отдельной строке.
#
# **Формат выходных данных:** <br>
# Программа должна вывести текст в соответствии с условием задачи.
#
# **Примечание №1:** <br>
# Между firstname lastname вставьте пробел =)
#
# ## sample_input:
# Anthony <br>
# Joshua <br>
#
# ## sample_output:
# Hello Anthony Joshua! You just delved into Python

# %%
# date: 18.09.2021

name, surname = input(), input()
print('Hello', name, surname + '!', 'You just delved into Python')

# %%
# date: 18.11.2022

print(f'Hello {input()} {input()}! You just delved into Python')
# Out:
# Hello Anthony Joshua! You just delved into Python

# %% [markdown]
# -----

# %% [markdown]
# # step_07 - Футбольная команда
# Напишите программу, которая считывает с клавиатуры название футбольной команды и выводит фразу: <br>
# *«Футбольная команда [введённая строка] имеет длину [длина введённой строки] символов»*.
#
# **Формат входных данных:** <br>
# На вход программе подаётся строка – название футбольной команды.
#
# **Формат выходных данных:** <br>
# Программа должна вывести текст в соответствии с условием задачи.
#
# ## sample_input:
# Barcelona <br>
#
# ## sample_output:
# Футбольная команда Barcelona имеет длину 9 символов

# %%
# date: 18.09.2021

team = input()
print("Футбольная команда", team, "имеет длину", len(team), "символов")

# %%
# date: 18.11.2022

print(f"Футбольная команда {(team := input())} имеет длину {len(team)} символов")
# Out:
# Футбольная команда Barcelona имеет длину 9 символов

# %% [markdown]
# # step_08 - Три города
# Даны названия трех городов. Напишите программу, которая определяет самое короткое и самое длинное название города.
#
# **Формат входных данных:** <br>
# На вход программе подаётся названия трех городов, каждое на отдельной строке.
#
# **Формат выходных данных:** <br>
# Программа должна вывести самое короткое и длинное название города, каждое на отдельной строке.
#
# **Примечание №1:** <br>
# Гарантируется, что длины названий всех трех городов различны.
#
# ## sample_input:
# Москва <br>
# Санкт-Петербург <br>
# Екатеринбург <br>
#
# ## sample_output:
# Москва <br>
# Санкт-Петербург <br>

# %%
# date: 18.09.2021

city1, city2, city3 = input(), input(), input()
print(min(city1, city2, city3, key = len),
      max(city1, city2, city3, key = len),
      sep = '\n')
# Out:
# Москва
# Санкт-Петербург

# %% [markdown]
# # step_09 - Арифметические строки
# Вводятся 3 строки в случайном порядке. Напишите программу, которая выясняет можно ли из длин этих строк построить возрастающую арифметическую прогрессию.
#
# **Формат входных данных:** <br>
# На вход программе подаются три строки, каждая на отдельной строке.
#
# **Формат выходных данных:** <br>
# Программа должна вывести строку *«YES»*, если из длин введенных слов можно построить арифметическую прогрессию, *«NO»* в ином случае.
#
# ## sample_input:
# abc <br>
# a <br>
# abcde <br>
#
# ## sample_output:
# YES

# %%
# date: 18.09.2021

a, b, c = len(input()), len(input()), len(input())

if (2 * b - c - a) * (2 * c - b - a) * (2 * a - b - c) == 0:
    print('YES')
else:
    print('NO')
# Out:
# YES

# %%
from os import chdir
chdir('/Users/dmitrijkolganov/Yandex.Disk.localized/GitHub/pet_projects')  # >)

from MathStat import Math, Sorting  # lib from my pet_projects

num_list: list = [len(input()), len((input())), len(input())]

print('YES' if Math.Progression.Arithmetic.is_progression(Sorting.insertion_sort(num_list)) else 'NO')
# Out:
# YES

# %% [markdown]
# ---

# %% [markdown]
# # step_12 - Цвет настроения синий
# Напишите программу, которая считывает одну строку, после чего выводит *«YES»*, если во введённой строке есть подстрока *«синий»* и *«NO»* в противном случае.
#
# **Формат входных данных:** <br>
# На вход программе подается одна строка.
#
# **Формат выходных данных:** <br>
# Программа должна вывести текст в соответствии с условием задачи.
#
# ## sample_input:
# Какой хороший день! <br>
#
# ## sample_output:
# NO

# %%
# date: 18.09.2021

s = input()
if 'синий' in s:
    print('YES')
else:
    print('NO')

# %%
# date: 18.11.2022

print('YES' if 'синий' in input() else 'NO')
# Out:
# NO

# %% [markdown]
# # step_13 - Отдыхаем ли?
# Напишите программу, которая считывает одну строку, после чего выводит *«YES»*, если во введённой строке есть подстрока *«суббота»* или *«воскресенье»*, и *«NO»* в противном случае.
#
# **Формат входных данных:** <br>
# На вход программе подается одна строка.
#
# **Формат выходных данных:** <br>
# Программа должна вывести текст в соответствии с условием задачи.
#
# ## sample_input:
# Какой сегодня день недели? <br>
#
# ## sample_output:
# NO

# %%
# date: 18.09.2021

s = input()
print('YES' if 'суббота' in s or 'воскресенье' in s else 'NO')

# %%
# date: 18.11.2022

print('YES' if 'суббота' in (text := input()) or 'воскресенье' in text else 'NO')
# Out:
# NO

# %% [markdown]
# # step_14 - Корректный email
# Будем считать email адрес корректным, если в нем есть символ собачки $@$ и точки. Напишите программу проверяющую корректность email адреса.
#
# **Формат входных данных:** <br>
# На вход программе подаётся одна строка – email адрес.
#
# **Формат выходных данных:** <br>
# Программа должна вывести строку *«YES»*, если email адрес является корректным и *«NO»* в ином случае.
#
# **Примечание №1:** <br>
# Наличие символов $@$ и $.$ недостаточно для корректности email адреса, однако их отсутствие гарантировано влечёт за собой неверный email.
#
# ## sample_input:
# aaaa@bbb.com
#
# ## sample_output:
# YES

# %%
# date: 18.11.2022

print('YES' if '@' in (mail := input()) and '.' in mail else 'NO')
# Out:
# YES
