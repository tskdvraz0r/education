# %% [markdown]
# # step_08 - Принадлежность 1
# Напишите программу, которая принимает целое число xx и определяет, принадлежит ли данное число указанному промежутку.
#
# *Формат входных данных:* <br>
# На вход программе подаётся целое число xx.
#
# *Формат выходных данных:* <br>
# Программа должна вывести текст в соответствии с условием задачи.
#
# ![img_08](https://ucarecdn.com/9bd3a69a-d538-41a2-aefb-e76386c653f9/)
#
# *Примечание №1:*
# Если точка выколотая, то граница не включается, если точка закрашенная, то граница включается.
#
# ## sample_input:
# 2
#
# ## sample_output:
# Принадлежит

# %%
# date: 17.11.2022

print('Принадлежит' if -1 < (num := int(input())) < 17 else 'Не принадлежит')
# Out:
# Принадлежит

# %% [markdown]
# -----

# %% [markdown]
# # step_09 - Принадлежность 2
# Напишите программу, которая принимает целое число xx и определяет, принадлежит ли данное число указанным промежуткам.
#
# *Формат входных данных:*
# На вход программе подаётся целое число $x$.
#
# *Формат выходных данных:*
# Программа должна вывести текст в соответствии с условием задачи.
#
# ![img_09](https://ucarecdn.com/5d994476-13fb-40aa-a529-4fd12c9e424a/)
#
# *Примечание №1:*
# Если точка выколотая, то граница не включается, если точка закрашенная, то граница включается.
#
# ## sample_input:
# -44
#
# ## sample_output:
# Принадлежит

# %%
# date: 17.11.2022

print('Принадлежит' if not -3 < (num := int(input())) < 7 else 'Не принадлежит')
# Out:
# Принадлежит

# %% [markdown]
# -----

# %% [markdown]
# # step_10 - Принадлежность 3
# Напишите программу, которая принимает целое число xx и определяет, принадлежит ли данное число указанным промежуткам.
#
# *Формат входных данных:*
# На вход программе подаётся целое число xx.
#
# *Формат выходных данных:*
# Программа должна вывести текст в соответствии с условием задачи.
#
# ![img_10](https://ucarecdn.com/4659a972-d8f5-4186-90ed-38dfdacf17fb/)
#
# *Примечание №1:*
# Если точка выколотая, то граница не включается, если точка закрашенная, то граница включается.
#
# ## sample_input:
# -332
#
# ## sample_output:
# Не принадлежит

# %% [markdown]
# -----

# %%
# date: 17.11.2022

print('Принадлежит' if (-2 >= (num := int(input())) > -30) or (7 < num <= 25) else 'Не принадлежит')
# Out:
# Не принадлежит

# %% [markdown]
# # step_11 - Красивое число 🌶️
# Назовем число красивым, если оно является четырехзначным и делится нацело на 77 или на 1717. Напишите программу, определяющую, является ли введённое число красивым. Программа должна вывести «YES», если число является красивым, или «NO» в противном случае.
#
# *Формат входных данных:*
# На вход программе подаётся натуральное число.
#
# *Формат выходных данных:*
# Программа должна вывести текст в соответствии с условием задачи.
#
# ## sample_input:
# 1043
#
# ## sample_output:
# YES

# %%
# date: 17.11.2022

print('YES' if (1000 <= (num := int(input())) <= 9999) and ((num % 7 == 0) or (num % 17 == 0)) else 'NO')
# Out:
# YES

# %% [markdown]
# # step_12 - Неравенство треугольника
# Напишите программу, которая принимает три положительных числа и определяет, существует ли невырожденный треугольник с такими сторонами.
#
# *Формат входных данных:*
# На вход программе подаётся три положительных целых числа.
#
# *Формат выходных данных:*
# Программа должна вывести «YES» или «NO» в соответствии с условием задачи.
#
# *Примечание №1:*
# Треугольник существует, если выполняется неравенство треугольника.
#
# ## sample_input:
# 5
# 2
# 3
#
# ## sample_output:
# NO

# %%
# date: 17.11.2022

print('YES' if ((a := int(input())) < ((b := int(input())) + (c := int(input())))) and (b < (c + a)) and (c < (a + b)) else 'NO')
# Out:
# NO

# %% [markdown]
# # step_13 - Високосный год
# Напишите программу, которая определяет, является ли год с данным номером високосным. Если год является високосным, то выведите «YES», иначе выведите «NO».
#
# Год является високосным, если его номер кратен 4, но не кратен 100, или если он кратен 400.
#
# *Формат входных данных:*
# На вход программе подаётся натуральное число.
#
# *Формат выходных данных:*
# Программа должна вывести текст в соответствии с условием задачи.
#
# ## sample_input:
# 2020
#
# ## sample_output:
# YES

# %%
# date: 17.11.2022

print('YES' if int(a := int(input())) % 4 == 0 and a % 100 != 0 or a % 400 == 0 else 'NO')
# Out:
# YES

# %% [markdown]
# # step_14 - Ход ладьи
# Даны две различные клетки шахматной доски. Напишите программу, которая определяет, может ли ладья попасть с первой клетки на вторую одним ходом. Программа получает на вход четыре числа от 1 до 8 каждое, задающие номер столбца и номер строки сначала для первой клетки, потом для второй клетки. Программа должна вывести «YES», если из первой клетки ходом ладьи можно попасть во вторую, или «NO» в противном случае.
#
# *Формат входных данных:*
# На вход программе подаётся четыре числа от 1 до 8.
#
# *Формат выходных данных:*
# Программа должна вывести текст в соответствии с условием задачи.
#
# *Примечание №1:*
# Шахматная ладья ходит по горизонтали или вертикали.
#
# ![img_14](https://ucarecdn.com/c13b2aac-577c-45a5-b29e-7136842cb955/)
#
# ## sample_input:
# 4
# 4
# 5
# 4
#
# ## sample_output:
# YES

# %%
# date: 17.11.2022

x0= int(input())
y0= int(input())
x1= int(input())
y1= int(input())

if x1 == x0 and 1 <= y1 <=8 or y1 == y0 and 1 <= x1 <=8:
    print('YES')
else:
    print('NO')
# Out:
# YES

# %% [markdown]
# # step_15 - Ход короля 🌶️
# Даны две различные клетки шахматной доски. Напишите программу,  которая определяет, может ли король попасть с первой клетки на вторую одним ходом. Программа получает на вход четыре числа от 1 до 8 каждое, задающие номер столбца и номер строки сначала для первой клетки, потом для второй клетки. Программа должна вывести «YES», если из первой клетки ходом короля можно попасть во вторую, или «NO» в противном случае.
#
# *Формат входных данных:*
# На вход программе подаётся четыре числа от 1 до 8.
#
# *Формат выходных данных:*
# Программа должна вывести текст в соответствии с условием задачи.
#
# *Примечание №1:*
# Шахматный король ходит по горизонтали, вертикали и диагонали, но только на 1 клетку.
#
# ![img_15](https://ucarecdn.com/e759d185-a6d3-47c8-96b2-7b52fa03af09/)
#
# ## sample_input:
# 4
# 4
# 5
# 5
#
# ## sample_output:
# YES

# %%
# date: 17.11.2022

x_0, x_1, y_0, y_1 = int(input()), int(input()), int(input()), int(input())

print('YES' if (-1 <= x_0 - y_0 <= 1) and (-1 <= x_1 - y_1 <= 1) else 'NO')
# Out:
# YES
